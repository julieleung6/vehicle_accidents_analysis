# %%
#importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
#uploading the dataset
df = pd.read_csv('../data/US_Accidents_March23.csv')

# %%
#displaying all the columns
pd.set_option('display.max_columns', None)
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  \
# 0  39.865147 -84.058723      NaN      NaN          0.01
# 1  39.928059 -82.831184      NaN      NaN          0.01
# 2  39.063148 -84.032608      NaN      NaN          0.01
# 3  39.747753 -84.205582      NaN      NaN          0.01
# 4  39.627781 -84.188354      NaN      NaN          0.01
#
#                                          Description  \
# 0  Right lane blocked due to accident on I-70 Eas...
# 1  Accident on Brice Rd at Tussing Rd. Expect del...
# 2  Accident on OH-32 State Route 32 Westbound at ...
# 3  Accident on I-75 Southbound at Exits 52 52B US...
# 4  Accident on McEwen Rd at OH-725 Miamisburg Cen...
#
#                       Street          City      County State     Zipcode  \
# 0                     I-70 E        Dayton  Montgomery    OH       45424
# 1                   Brice Rd  Reynoldsburg    Franklin    OH  43068-3402
# 2             State Route 32  Williamsburg    Clermont    OH       45176
# 3                     I-75 S        Dayton  Montgomery    OH       45417
# 4  Miamisburg Centerville Rd        Dayton  Montgomery    OH       45459
#
#   Country    Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# 0      US  US/Eastern         KFFO  2016-02-08 05:58:00            36.9
# 1      US  US/Eastern         KCMH  2016-02-08 05:51:00            37.9
# 2      US  US/Eastern         KI69  2016-02-08 06:56:00            36.0
# 3      US  US/Eastern         KDAY  2016-02-08 07:38:00            35.1
# 4      US  US/Eastern         KMGY  2016-02-08 07:53:00            36.0
#
#    Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  \
# 0            NaN         91.0         29.68            10.0           Calm
# 1            NaN        100.0         29.65            10.0           Calm
# 2           33.3        100.0         29.67            10.0             SW
# 3           31.0         96.0         29.64             9.0             SW
# 4           33.3         89.0         29.65             6.0             SW
#
#    Wind_Speed(mph)  Precipitation(in) Weather_Condition  Amenity   Bump  \
# 0              NaN               0.02        Light Rain    False  False
# 1              NaN               0.00        Light Rain    False  False
# 2              3.5                NaN          Overcast    False  False
# 3              4.6                NaN     Mostly Cloudy    False  False
# 4              3.5                NaN     Mostly Cloudy    False  False
#
#    Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0     False     False     False    False    False       False    False  False
# 1     False     False     False    False    False       False    False  False
# 2     False     False     False    False    False       False    False  False
# 3     False     False     False    False    False       False    False  False
# 4     False     False     False    False    False       False    False  False
#
#    Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0            False           False         False          Night
# 1            False           False         False          Night
# 2            False            True         False          Night
# 3            False           False         False          Night
# 4            False            True         False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day

# %%
#getting more info on the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 2.0+ GB

# %%
#seeing how many nulls are in each column
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# Weather_Condition         173459
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset             23246
# Civil_Twilight             23246
# Nautical_Twilight          23246
# Astronomical_Twilight      23246
# dtype: int64

# %%
#note we have class imbalanced
df['Severity'].value_counts()
# Out:
# Severity
# 2    6156981
# 3    1299337
# 4     204710
# 1      67366
# Name: count, dtype: int64

# %%
#seeing how many countries we are working with
df['Country'].unique()
# Out:
# array(['US'], dtype=object)

# %%
#dropping columns we won't be using
df = df.drop(columns=['Source', 'Country', 'Airport_Code', 'Timezone', 'Wind_Direction'])

# %%
#making sure the format for all the values are the same
#deleting the value after the .
df['Start_Time'] = [str(value).split('.')[0] for value in df['Start_Time']]
df['End_Time'] = [str(value).split('.')[0] for value in df['End_Time']]

# %%
# df.loc[3639775, 'Start_Time'] = '2017-07-23 04:21:01'
# df.loc[3639776, 'Start_Time'] = '2017-07-23 05:18:46'

# %%
#making sure it's removed
df['End_Time'][3639777]
# Out:
# '2017-07-23 11:36:01'

# %%
#changing the format to date/time
df['Start_Time'] = pd.to_datetime(df['Start_Time'], format="%Y-%m-%d %H:%M:%S")
df['End_Time'] = pd.to_datetime(df['End_Time'], format="%Y-%m-%d %H:%M:%S")
df['Weather_Timestamp'] = pd.to_datetime(df['Weather_Timestamp'], format="%Y-%m-%d %H:%M:%S")

# %%
#checking to see the Start_Time, End_Time, and Weather_Timestamp are datetime types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 41 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               datetime64[ns]
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Street                 object
#  11  City                   object
#  12  County                 object
#  13  State                  object
#  14  Zipcode                object
#  15  Weather_Timestamp      datetime64[ns]
#  16  Temperature(F)         float64
#  17  Wind_Chill(F)          float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
#  21  Wind_Speed(mph)        float64
#  22  Precipitation(in)      float64
#  23  Weather_Condition      object
#  24  Amenity                bool
#  25  Bump                   bool
#  26  Crossing               bool
#  27  Give_Way               bool
#  28  Junction               bool
#  29  No_Exit                bool
#  30  Railway                bool
#  31  Roundabout             bool
#  32  Station                bool
#  33  Stop                   bool
#  34  Traffic_Calming        bool
#  35  Traffic_Signal         bool
#  36  Turning_Loop           bool
#  37  Sunrise_Sunset         object
#  38  Civil_Twilight         object
#  39  Nautical_Twilight      object
#  40  Astronomical_Twilight  object
# dtypes: bool(13), datetime64[ns](3), float64(12), int64(1), object(12)
# memory usage: 1.7+ GB

# %% [markdown]
# ## Duration of the Accidents

# %%
#creating a new column that shows how long each of the accident were
df['Duration'] = df['End_Time'] - df['Start_Time']

# %%
df['Duration'].value_counts()
# Out:
# Duration
# 0 days 06:00:00    369307
# 0 days 00:30:00    116096
# 0 days 00:45:00     70075
# 0 days 01:15:00     61374
# 0 days 01:00:00     61173
#                     ...
# 1 days 02:30:42         1
# 1 days 02:20:59         1
# 1 days 02:40:05         1
# 0 days 11:42:56         1
# 1 days 22:37:30         1
# Name: count, Length: 74038, dtype: int64

# %%
#seeing the longest duration time for the accidents
df['Duration'].sort_values(ascending=False)
# Out:
# 4774200   1953 days 10:19:00
# 5015643   1953 days 10:19:00
# 5358306   1553 days 01:25:45
# 5035157   1553 days 00:35:32
# 4540426   1553 days 00:35:32
#                  ...
# 5720486      0 days 00:02:30
# 5455635      0 days 00:02:00
# 5288952      0 days 00:02:00
# 3184392      0 days 00:01:55
# 2555552      0 days 00:01:13
# Name: Duration, Length: 7728394, dtype: timedelta64[ns]

# %%
#looking into an accident that has duration time ~4 years!!
df[df['Duration']== '1553 days 01:25:45']
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 5358306  A-5399002         2 2018-04-19 09:24:00 2022-07-20 10:49:45
#
#          Start_Lat  Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 5358306  40.894453 -72.470099  40.895494 -72.457948         0.639
#
#                                                Description      Street  \
# 5358306  NYSDOT - Region 10: Crash on NY 27 eastbound a...  Inlet Rd W
#
#                 City   County State Zipcode   Weather_Timestamp  \
# 5358306  Southampton  Suffolk    NY   11968 2018-04-19 09:20:00
#
#          Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 5358306            41.0           37.1         91.0         29.65
#
#          Visibility(mi)  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# 5358306            10.0              5.8                NaN          Overcast
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 5358306    False  False     False     False     False    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 5358306       False    False  False            False           False
#
#          Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 5358306         False            Day            Day               Day
#
#         Astronomical_Twilight           Duration
# 5358306                   Day 1553 days 01:25:45

# %%
df['Description'][5358306]
# Out:
# 'NYSDOT - Region 10: Crash on NY 27 eastbound area of Exit 66 - North Shore Highway; CR 39; North Shore Road (Suffolk) left lane closed'

# %%
#seeing why we have an accident that lasted for 6 years!!
df[df.Duration == '1953 days 10:19:00']
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 4774200  A-4810425         2 2016-10-21 07:26:00 2022-02-25 17:45:00
# 5015643  A-5053641         2 2016-10-21 07:26:00 2022-02-25 17:45:00
#
#          Start_Lat  Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 4774200  39.722369 -75.537494  39.717247 -75.549731         0.740
# 5015643  39.721273 -75.538913  39.718263 -75.543893         0.337
#
#                                                Description   Street  \
# 4774200  Construction on I-495 SB near TERMINAL AVE Rig...  I-495 S
# 5015643  Construction on I-495 SB near TERMINAL AVE Rig...    I-495
#
#                City      County State Zipcode   Weather_Timestamp  \
# 4774200  Wilmington  New Castle    DE   19801 2016-10-21 07:46:00
# 5015643  Wilmington  New Castle    DE   19801 2016-10-21 07:46:00
#
#          Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 4774200            66.2            NaN         94.0         29.78
# 5015643            66.2            NaN         94.0         29.78
#
#          Visibility(mi)  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# 4774200             1.8              8.1                NaN          Overcast
# 5015643             1.8              8.1                NaN          Overcast
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 4774200    False  False     False     False     False    False    False
# 5015643    False  False     False     False     False    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 4774200       False    False  False            False           False
# 5015643       False    False  False            False           False
#
#          Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 4774200         False            Day            Day               Day
# 5015643         False            Day            Day               Day
#
#         Astronomical_Twilight           Duration
# 4774200                   Day 1953 days 10:19:00
# 5015643                   Day 1953 days 10:19:00

# %%
df['Description'][4774200]
#Must be an error while inputting the data because its unfathomable to believe the delay lasted for 6 years
# Out:
# 'Construction on I-495 SB near TERMINAL AVE Right lane blocked. Expect delays.'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 42 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               datetime64[ns]
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Street                 object
#  11  City                   object
#  12  County                 object
#  13  State                  object
#  14  Zipcode                object
#  15  Weather_Timestamp      datetime64[ns]
#  16  Temperature(F)         float64
#  17  Wind_Chill(F)          float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
#  21  Wind_Speed(mph)        float64
#  22  Precipitation(in)      float64
#  23  Weather_Condition      object
#  24  Amenity                bool
#  25  Bump                   bool
#  26  Crossing               bool
#  27  Give_Way               bool
#  28  Junction               bool
#  29  No_Exit                bool
#  30  Railway                bool
#  31  Roundabout             bool
#  32  Station                bool
#  33  Stop                   bool
#  34  Traffic_Calming        bool
#  35  Traffic_Signal         bool
#  36  Turning_Loop           bool
#  37  Sunrise_Sunset         object
#  38  Civil_Twilight         object
#  39  Nautical_Twilight      object
#  40  Astronomical_Twilight  object
#  41  Duration               timedelta64[ns]
# dtypes: bool(13), datetime64[ns](3), float64(12), int64(1), object(12), timedelta64[ns](1)
# memory usage: 1.8+ GB

# %% [markdown]
# ## Number of Accidents per Hour

# %%
#The number of accidents throughout the day
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True); #extracting the hour from the timestamp

# Set the tick locations
plt.xticks(range(0, 24, 2))  # Set ticks every 2 hours

# Add grid lines
plt.gca().xaxis.grid(True)

plt.show()
# Out:
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/3756996199.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True); #extracting the hour from the timestamp

# %% [markdown]
# We can see a big uptick in accidents during the morning/afternoon rush hour, coinciding with the times when most people are commuting.

# %% [markdown]
# ## Number of Accidents per month

# %%
#creating new columns for the month and week
df['Month'] = df.Start_Time.dt.month

# %%
#The number of accidents throughout the day
sns.distplot(df.Start_Time.dt.month, bins=12, kde=False, norm_hist=False) #extracting the hour from the timestamp

plt.xticks(range(1, 13, 1))

plt.show();
# Out:
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/1220020651.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.month, bins=12, kde=False, norm_hist=False) #extracting the hour from the timestamp

# %% [markdown]
# As we can see there is an increase in accidents around the end of the year coinciding with the holiday travels.

# %%
df['Month'].value_counts()
# Out:
# Month
# 12    847343
# 11    760165
# 1     751946
# 10    675130
# 2     658984
# 9     651381
# 8     599666
# 4     587300
# 6     571373
# 5     558176
# 3     554595
# 7     512335
# Name: count, dtype: int64

# %%
df.groupby('Month').size()
# Out:
# Month
# 1     751946
# 2     658984
# 3     554595
# 4     587300
# 5     558176
# 6     571373
# 7     512335
# 8     599666
# 9     651381
# 10    675130
# 11    760165
# 12    847343
# dtype: int64

# %% [markdown]
# ### Accidents by Weather Condition

# %%
#seeing which words in weather condition has the most weights
data = df['Weather_Condition'].value_counts().to_dict()
wc = WordCloud(width = 900, height = 800, background_color ='white', min_font_size = 10).generate_from_frequencies(data)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# Interestingly, the majority of accidents occur under fair/clear or cloudy weather conditions rather than during snow or rain.

# %% [markdown]
# ### States with the most accidents

# %%
states_by_accident = df.State.value_counts()
states_by_accident[:10]
# Out:
# State
# CA    1741433
# FL     880192
# TX     582837
# SC     382557
# NY     347960
# NC     338199
# VA     303301
# PA     296620
# MN     192084
# OR     179660
# Name: count, dtype: int64

# %%
states_by_accident[:10].plot(kind = 'barh', title='Top 10 States by Accident');

# %%
#only using the top 6 states with the most accidents

# Create a list of states to keep
states_to_keep = ['CA', 'FL', 'TX', 'SC', 'NY', 'NC']

# Create a new DataFrame by filtering the rows
new_df = df[df['State'].isin(states_to_keep)]

# %%
#checking to see how many null values after dropping most states
new_df.isnull().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  1849447
# End_Lng                  1849447
# Distance(mi)                   0
# Description                    5
# Street                      5875
# City                          72
# County                         0
# State                          0
# Zipcode                     1367
# Weather_Timestamp          55660
# Temperature(F)             81130
# Wind_Chill(F)            1188155
# Humidity(%)                86285
# Pressure(in)               65381
# Visibility(mi)             75537
# Wind_Speed(mph)           312569
# Precipitation(in)        1244218
# Weather_Condition          72753
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset              9550
# Civil_Twilight              9550
# Nautical_Twilight           9550
# Astronomical_Twilight       9550
# Duration                       0
# Month                          0
# dtype: int64

# %% [markdown]
# ### The Cities within the Top 6 States with the Highest Number of Accidents

# %%
cities_by_accident = new_df.City.value_counts()
cities_by_accident
# Out:
# City
# Miami             186768
# Houston           169428
# Los Angeles       156491
# Charlotte         138345
# Dallas            130396
#                    ...
# Brookeland             1
# Purdon                 1
# Port St. Lucie         1
# West Leyden            1
# Pond Eddy              1
# Name: count, Length: 4482, dtype: int64

# %%
cities_by_accident[:10].plot(kind = 'barh');

# %%
new_df.describe()
# Out:
#            Severity                     Start_Time  \
# count  4.273178e+06                        4273178
# mean   2.168610e+00  2020-06-06 07:35:50.217138432
# min    1.000000e+00            2016-03-22 17:44:13
# 25%    2.000000e+00     2018-11-20 13:02:16.500000
# 50%    2.000000e+00            2020-11-23 16:15:00
# 75%    2.000000e+00            2022-01-26 07:50:30
# max    4.000000e+00            2023-03-31 23:25:30
# std    4.282122e-01                            NaN
#
#                             End_Time     Start_Lat     Start_Lng  \
# count                        4273178  4.273178e+06  4.273178e+06
# mean   2020-06-06 09:48:02.834282752  3.368302e+01 -9.837515e+01
# min              2016-03-22 22:05:41  2.455480e+01 -1.243750e+02
# 25%              2018-11-20 13:50:56  3.025212e+01 -1.182230e+02
# 50%       2020-11-23 22:05:27.500000  3.402754e+01 -9.561913e+01
# 75%    2022-01-26 09:16:42.750000128  3.611967e+01 -8.083998e+01
# max              2023-03-31 23:58:00  4.500189e+01 -7.186103e+01
# std                              NaN  4.280859e+00  1.852925e+01
#
#             End_Lat       End_Lng  Distance(mi)  \
# count  2.423731e+06  2.423731e+06  4.273178e+06
# mean   3.359181e+01 -9.949935e+01  4.577582e-01
# min    2.456601e+01 -1.244002e+02  0.000000e+00
# 25%    2.992466e+01 -1.183003e+02  0.000000e+00
# 50%    3.402465e+01 -9.681045e+01  2.000000e-02
# 75%    3.677185e+01 -8.077439e+01  3.380000e-01
# max    4.499732e+01 -7.194368e+01  3.336300e+02
# std    4.492968e+00  1.900653e+01  1.434502e+00
#
#                    Weather_Timestamp  Temperature(F)  Wind_Chill(F)  \
# count                        4217518    4.192048e+06   3.085023e+06
# mean   2020-06-05 21:52:27.412123392    6.631451e+01   6.473455e+01
# min              2016-03-22 17:50:00   -7.780000e+01  -8.000000e+01
# 25%              2018-11-20 12:53:00    5.590000e+01   5.400000e+01
# 50%              2020-11-23 17:53:00    6.800000e+01   6.700000e+01
# 75%              2022-01-26 07:53:00    7.800000e+01   7.800000e+01
# max              2023-03-31 23:53:00    2.070000e+02   2.070000e+02
# std                              NaN    1.561716e+01   1.751587e+01
#
#         Humidity(%)  Pressure(in)  Visibility(mi)  Wind_Speed(mph)  \
# count  4.186893e+06  4.207797e+06    4.197641e+06     3.960609e+06
# mean   6.409616e+01  2.973442e+01    9.188709e+00     7.423251e+00
# min    1.000000e+00  0.000000e+00    0.000000e+00     0.000000e+00
# 25%    4.800000e+01  2.962000e+01    1.000000e+01     3.500000e+00
# 50%    6.600000e+01  2.991000e+01    1.000000e+01     7.000000e+00
# 75%    8.300000e+01  3.004000e+01    1.000000e+01     1.000000e+01
# max    1.000000e+02  5.863000e+01    1.400000e+02     1.087000e+03
# std    2.268640e+01  6.158423e-01    2.315648e+00     5.432697e+00
#
#        Precipitation(in)                   Duration         Month
# count       3.028960e+06                    4273178  4.273178e+06
# mean        8.342249e-03  0 days 02:12:12.617144663  6.690366e+00
# min         0.000000e+00            0 days 00:01:55  1.000000e+00
# 25%         0.000000e+00            0 days 00:33:30  3.000000e+00
# 50%         0.000000e+00            0 days 01:15:00  7.000000e+00
# 75%         0.000000e+00            0 days 02:06:43  1.000000e+01
# max         2.400000e+01         1553 days 01:25:45  1.200000e+01
# std         1.283089e-01  2 days 17:25:01.597568843  3.628719e+00

# %% [markdown]
# ### Distributions of weather related columns

# %%
#examing the distribution of the temp to see what to fill the missing values with

fig, axes = plt.subplots(3, 2, figsize=(16, 16))

sns.histplot(data=new_df, x='Temperature(F)', bins='auto', ax=axes[0,0])
sns.histplot(data=new_df, x='Wind_Chill(F)', bins='auto', ax=axes[0,1])
sns.histplot(data=new_df, x='Humidity(%)', bins='auto', ax=axes[1,0])
sns.histplot(data=new_df, x='Pressure(in)', bins='auto', ax=axes[1,1])
sns.histplot(data=new_df, x='Visibility(mi)', bins='auto', ax=axes[2,0])
sns.histplot(data=new_df, x='Wind_Speed(mph)', bins='auto', ax=axes[2,1])
plt.tight_layout()

plt.figure(figsize=(10, 10))
sns.histplot(data=new_df, x='Precipitation(in)', bins=100)

plt.show()

# %%
#the plot for Wind Speed looks funny, lets take a closer look
new_df.sort_values(by='Wind_Speed(mph)', ascending=False)
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 6274606  A-6320814         2 2021-12-16 12:31:00 2021-12-16 14:44:36
# 7092904  A-7142243         2 2020-03-28 14:49:27 2020-03-28 16:09:25
# 114588    A-114595         3 2016-06-13 18:44:57 2016-06-13 19:29:57
# 3414544  A-3424427         2 2016-06-13 15:58:19 2016-06-13 21:58:19
# 114640    A-114647         2 2016-06-13 20:19:08 2016-06-13 21:04:08
# ...            ...       ...                 ...                 ...
# 7727583  A-7776951         2 2019-08-22 09:01:20 2019-08-22 09:29:38
# 7727610  A-7776978         2 2019-08-22 16:54:48 2019-08-22 17:22:17
# 7727934  A-7777302         2 2019-08-22 15:01:34 2019-08-22 15:31:27
# 7728066  A-7777434         4 2019-08-23 17:28:24 2019-08-23 17:55:48
# 7728332  A-7777700         2 2019-08-23 10:02:30 2019-08-23 10:31:24
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 6274606  37.328360 -120.559242  37.328225 -120.558982         0.017
# 7092904  27.209430  -80.333700  27.209430  -80.333700         0.000
# 114588   34.320553 -118.495262        NaN         NaN         0.000
# 3414544  34.234870 -118.412160  34.232059 -118.407485         0.330
# 114640   34.266048 -118.467438        NaN         NaN         0.000
# ...            ...         ...        ...         ...           ...
# 7727583  27.999900  -82.335570  28.002780  -82.320840         0.920
# 7727610  27.981630  -82.285930  27.981630  -82.285930         0.000
# 7727934  34.148600 -118.072990  34.148260 -118.075570         0.149
# 7728066  27.965090  -82.447270  27.968840  -82.453370         0.454
# 7728332  37.836581 -122.011649  37.838359 -122.014603         0.203
#
#                                                Description  \
# 6274606               Accident from N Gurr Rd to Ashby Rd.
# 7092904       At SE Becker Rd/Exit 138 - Earlier accident.
# 114588   Accident on I-5 Trk Northbound near I-5. On th...
# 3414544                              At CA-170 - Accident.
# 114640   Accident on CA-118 Westbound before Exits 42A ...
# ...                                                    ...
# 7727583      At I-75/Exit 9 - Accident. Left lane blocked.
# 7727610                         At Parsons Ave - Accident.
# 7727934  Between Michillinda Ave and Rosemead Blvd - Ac...
# 7728066  Ramp closed to I-4/Exit 45 - Road closed due t...
# 7728332       At Stone Valley Rd - Accident. Lane blocked.
#
#                       Street              City        County State  \
# 6274606             Ashby Rd           Atwater        Merced    CA
# 7092904         SW Becker Rd  Port Saint Lucie     St. Lucie    FL
# 114588                 I-5 N            Sylmar   Los Angeles    CA
# 3414544   Golden State Fwy S           Pacoima   Los Angeles    CA
# 114640   Ronald Reagan Fwy W     Mission Hills   Los Angeles    CA
# ...                      ...               ...           ...   ...
# 7727583                I-4 E             Tampa  Hillsborough    FL
# 7727610        S Parsons Ave           Seffner  Hillsborough    FL
# 7727934       Foothill Fwy W          Pasadena   Los Angeles    CA
# 7728066                I-4 W             Tampa  Hillsborough    FL
# 7728332              I-680 N          Danville  Contra Costa    CA
#
#             Zipcode   Weather_Timestamp  Temperature(F)  Wind_Chill(F)  \
# 6274606  95301-5406 2021-12-16 12:45:00            50.0           50.0
# 7092904       34953 2020-03-28 14:55:00            84.0           84.0
# 114588        91342 2016-06-13 16:53:00            71.6            NaN
# 3414544       91331 2016-06-13 16:53:00            71.6            NaN
# 114640        91345 2016-06-13 16:53:00            71.6            NaN
# ...             ...                 ...             ...            ...
# 7727583       33610                 NaT             NaN            NaN
# 7727610  33584-4504                 NaT             NaN            NaN
# 7727934       91107                 NaT             NaN            NaN
# 7728066       33605                 NaT             NaN            NaN
# 7728332       94526 2019-08-23 09:53:00            76.0            NaN
#
#          Humidity(%)  Pressure(in)  Visibility(mi)  Wind_Speed(mph)  \
# 6274606        100.0         29.91            10.0           1087.0
# 7092904         51.0         30.06             7.0            984.0
# 114588          53.0         30.06            10.0            822.8
# 3414544         53.0         30.06            10.0            822.8
# 114640          53.0         30.06            10.0            822.8
# ...              ...           ...             ...              ...
# 7727583          NaN           NaN             NaN              NaN
# 7727610          NaN           NaN             NaN              NaN
# 7727934          NaN           NaN             NaN              NaN
# 7728066          NaN           NaN             NaN              NaN
# 7728332         56.0         29.72             NaN              NaN
#
#          Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# 6274606                0.0    Cloudy / Windy    False  False     False
# 7092904                0.0      Fair / Windy    False  False     False
# 114588                 NaN             Clear    False  False     False
# 3414544                NaN             Clear    False  False     False
# 114640                 NaN             Clear    False  False     False
# ...                    ...               ...      ...    ...       ...
# 7727583                NaN               NaN    False  False     False
# 7727610                NaN               NaN    False  False      True
# 7727934                NaN               NaN    False  False     False
# 7728066                NaN               NaN    False  False     False
# 7728332                0.0               NaN    False  False     False
#
#          Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 6274606     False     False    False    False       False    False  False
# 7092904     False     False    False    False       False    False  False
# 114588      False     False    False    False       False    False  False
# 3414544     False      True    False    False       False    False  False
# 114640      False     False    False    False       False    False  False
# ...           ...       ...      ...      ...         ...      ...    ...
# 7727583     False      True    False    False       False    False  False
# 7727610     False     False    False    False       False    False  False
# 7727934     False     False    False    False       False    False  False
# 7728066     False     False    False    False       False    False  False
# 7728332     False      True    False    False       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 6274606            False           False         False            Day
# 7092904            False           False         False            Day
# 114588             False           False         False            Day
# 3414544            False           False         False            Day
# 114640             False           False         False          Night
# ...                  ...             ...           ...            ...
# 7727583            False           False         False            Day
# 7727610            False            True         False            Day
# 7727934            False           False         False            Day
# 7728066            False           False         False            Day
# 7728332            False           False         False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 6274606            Day               Day                   Day
# 7092904            Day               Day                   Day
# 114588             Day               Day                   Day
# 3414544            Day               Day                   Day
# 114640             Day               Day                   Day
# ...                ...               ...                   ...
# 7727583            Day               Day                   Day
# 7727610            Day               Day                   Day
# 7727934            Day               Day                   Day
# 7728066            Day               Day                   Day
# 7728332            Day               Day                   Day
#
#                Duration  Month
# 6274606 0 days 02:13:36     12
# 7092904 0 days 01:19:58      3
# 114588  0 days 00:45:00      6
# 3414544 0 days 06:00:00      6
# 114640  0 days 00:45:00      6
# ...                 ...    ...
# 7727583 0 days 00:28:18      8
# 7727610 0 days 00:27:29      8
# 7727934 0 days 00:29:53      8
# 7728066 0 days 00:27:24      8
# 7728332 0 days 00:28:54      8
#
# [4273178 rows x 43 columns]

# %%
# Checking if the value is greater than 100 and dividing it by 10 if they are
new_df['Wind_Speed(mph)'] = new_df.loc[new_df['Wind_Speed(mph)'] > 100, 'Wind_Speed(mph)'] / 10
# Out:
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/162880586.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Wind_Speed(mph)'] = new_df.loc[new_df['Wind_Speed(mph)'] > 100, 'Wind_Speed(mph)'] / 10

# %%
new_df.sort_values(by='Wind_Speed(mph)', ascending=False)
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 6274606  A-6320814         2 2021-12-16 12:31:00 2021-12-16 14:44:36
# 7092904  A-7142243         2 2020-03-28 14:49:27 2020-03-28 16:09:25
# 114588    A-114595         3 2016-06-13 18:44:57 2016-06-13 19:29:57
# 3414544  A-3424427         2 2016-06-13 15:58:19 2016-06-13 21:58:19
# 114647    A-114654         3 2016-06-13 20:30:47 2016-06-13 21:15:47
# ...            ...       ...                 ...                 ...
# 7728389  A-7777757         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# 7728390  A-7777758         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# 7728391  A-7777759         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# 7728392  A-7777760         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# 7728393  A-7777761         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# 6274606  37.328360 -120.559242  37.328225 -120.558982         0.017
# 7092904  27.209430  -80.333700  27.209430  -80.333700         0.000
# 114588   34.320553 -118.495262        NaN         NaN         0.000
# 3414544  34.234870 -118.412160  34.232059 -118.407485         0.330
# 114647   34.266048 -118.450768        NaN         NaN         0.000
# ...            ...         ...        ...         ...           ...
# 7728389  34.002480 -117.379360  33.998880 -117.370940         0.543
# 7728390  32.766960 -117.148060  32.765550 -117.153630         0.338
# 7728391  33.775450 -117.847790  33.777400 -117.857270         0.561
# 7728392  33.992460 -118.403020  33.983110 -118.395650         0.772
# 7728393  34.133930 -117.230920  34.137360 -117.239340         0.537
#
#                                                Description  \
# 6274606               Accident from N Gurr Rd to Ashby Rd.
# 7092904       At SE Becker Rd/Exit 138 - Earlier accident.
# 114588   Accident on I-5 Trk Northbound near I-5. On th...
# 3414544                              At CA-170 - Accident.
# 114647   Accident on I-5 Northbound near Exits 156A 156...
# ...                                                    ...
# 7728389                           At Market St - Accident.
# 7728390    At Camino Del Rio/Mission Center Rd - Accident.
# 7728391  At Glassell St/Grand Ave - Accident. in the ri...
# 7728392     At CA-90/Marina Fwy/Jefferson Blvd - Accident.
# 7728393              At Highland Ave/Arden Ave - Accident.
#
#                       Street              City          County State  \
# 6274606             Ashby Rd           Atwater          Merced    CA
# 7092904         SW Becker Rd  Port Saint Lucie       St. Lucie    FL
# 114588                 I-5 N            Sylmar     Los Angeles    CA
# 3414544   Golden State Fwy S           Pacoima     Los Angeles    CA
# 114647   Ronald Reagan Fwy W     Mission Hills     Los Angeles    CA
# ...                      ...               ...             ...   ...
# 7728389         Pomona Fwy E         Riverside       Riverside    CA
# 7728390                I-8 W         San Diego       San Diego    CA
# 7728391     Garden Grove Fwy            Orange          Orange    CA
# 7728392      San Diego Fwy S       Culver City     Los Angeles    CA
# 7728393             CA-210 W          Highland  San Bernardino    CA
#
#             Zipcode   Weather_Timestamp  Temperature(F)  Wind_Chill(F)  \
# 6274606  95301-5406 2021-12-16 12:45:00            50.0           50.0
# 7092904       34953 2020-03-28 14:55:00            84.0           84.0
# 114588        91342 2016-06-13 16:53:00            71.6            NaN
# 3414544       91331 2016-06-13 16:53:00            71.6            NaN
# 114647        91345 2016-06-13 16:53:00            71.6            NaN
# ...             ...                 ...             ...            ...
# 7728389       92501 2019-08-23 17:53:00            86.0           86.0
# 7728390       92108 2019-08-23 18:53:00            70.0           70.0
# 7728391       92866 2019-08-23 18:53:00            73.0           73.0
# 7728392       90230 2019-08-23 18:51:00            71.0           71.0
# 7728393       92346 2019-08-23 20:50:00            79.0           79.0
#
#          Humidity(%)  Pressure(in)  Visibility(mi)  Wind_Speed(mph)  \
# 6274606        100.0         29.91            10.0           108.70
# 7092904         51.0         30.06             7.0            98.40
# 114588          53.0         30.06            10.0            82.28
# 3414544         53.0         30.06            10.0            82.28
# 114647          53.0         30.06            10.0            82.28
# ...              ...           ...             ...              ...
# 7728389         40.0         28.92            10.0              NaN
# 7728390         73.0         29.39            10.0              NaN
# 7728391         64.0         29.74            10.0              NaN
# 7728392         81.0         29.62            10.0              NaN
# 7728393         47.0         28.63             7.0              NaN
#
#          Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# 6274606                0.0    Cloudy / Windy    False  False     False
# 7092904                0.0      Fair / Windy    False  False     False
# 114588                 NaN             Clear    False  False     False
# 3414544                NaN             Clear    False  False     False
# 114647                 NaN             Clear    False  False     False
# ...                    ...               ...      ...    ...       ...
# 7728389                0.0              Fair    False  False     False
# 7728390                0.0              Fair    False  False     False
# 7728391                0.0     Partly Cloudy    False  False     False
# 7728392                0.0              Fair    False  False     False
# 7728393                0.0              Fair    False  False     False
#
#          Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 6274606     False     False    False    False       False    False  False
# 7092904     False     False    False    False       False    False  False
# 114588      False     False    False    False       False    False  False
# 3414544     False      True    False    False       False    False  False
# 114647      False     False    False    False       False    False  False
# ...           ...       ...      ...      ...         ...      ...    ...
# 7728389     False     False    False    False       False    False  False
# 7728390     False     False    False    False       False    False  False
# 7728391     False      True    False    False       False    False  False
# 7728392     False     False    False    False       False    False  False
# 7728393     False     False    False    False       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 6274606            False           False         False            Day
# 7092904            False           False         False            Day
# 114588             False           False         False            Day
# 3414544            False           False         False            Day
# 114647             False           False         False          Night
# ...                  ...             ...           ...            ...
# 7728389            False           False         False            Day
# 7728390            False           False         False            Day
# 7728391            False           False         False            Day
# 7728392            False           False         False            Day
# 7728393            False           False         False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 6274606            Day               Day                   Day
# 7092904            Day               Day                   Day
# 114588             Day               Day                   Day
# 3414544            Day               Day                   Day
# 114647             Day               Day                   Day
# ...                ...               ...                   ...
# 7728389            Day               Day                   Day
# 7728390            Day               Day                   Day
# 7728391            Day               Day                   Day
# 7728392            Day               Day                   Day
# 7728393            Day               Day                   Day
#
#                Duration  Month
# 6274606 0 days 02:13:36     12
# 7092904 0 days 01:19:58      3
# 114588  0 days 00:45:00      6
# 3414544 0 days 06:00:00      6
# 114647  0 days 00:45:00      6
# ...                 ...    ...
# 7728389 0 days 00:28:36      8
# 7728390 0 days 00:26:53      8
# 7728391 0 days 00:28:28      8
# 7728392 0 days 00:29:21      8
# 7728393 0 days 00:29:25      8
#
# [4273178 rows x 43 columns]

# %%
#filling in the null values with the mean values of each column
mean_value_temp = new_df['Temperature(F)'].mean()
mean_value_wind_chill = new_df['Wind_Chill(F)'].mean()
mean_value_humid = new_df['Humidity(%)'].mean()
mean_value_press = new_df['Pressure(in)'].mean()
mean_value_vis = new_df['Visibility(mi)'].mean()
mean_value_wind_speed = new_df['Wind_Speed(mph)'].mean()
mean_value_precip = new_df['Precipitation(in)'].mean()

new_df['Temperature(F)'].fillna(value=mean_value_temp, inplace=True)
new_df['Wind_Chill(F)'].fillna(value=mean_value_wind_chill, inplace=True)
new_df['Humidity(%)'].fillna(value=mean_value_humid, inplace=True)
new_df['Pressure(in)'].fillna(value=mean_value_press, inplace=True)
new_df['Visibility(mi)'].fillna(value=mean_value_vis, inplace=True)
new_df['Wind_Speed(mph)'].fillna(value=mean_value_wind_speed,inplace=True)
new_df['Precipitation(in)'].fillna(value=mean_value_precip, inplace=True)
# Out:
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/1472237199.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Temperature(F)'].fillna(value=mean_value_temp, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/1472237199.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Wind_Chill(F)'].fillna(value=mean_value_wind_chill, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/1472237199.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Humidity(%)'].fillna(value=mean_value_humid, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/1472237199.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Pressure(in)'].fillna(value=mean_value_press, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/1472237199.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Visibility(mi)'].fillna(value=mean_value_vis, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/1472237199.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Wind_Speed(mph)'].fillna(value=mean_value_wind_speed,inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_4753/1472237199.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Precipitation(in)'].fillna(value=mean_value_precip, inplace=True)

# %%
#checking to see if the columns above are updated
new_df.isnull().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  1849447
# End_Lng                  1849447
# Distance(mi)                   0
# Description                    5
# Street                      5875
# City                          72
# County                         0
# State                          0
# Zipcode                     1367
# Weather_Timestamp          55660
# Temperature(F)                 0
# Wind_Chill(F)                  0
# Humidity(%)                    0
# Pressure(in)                   0
# Visibility(mi)                 0
# Wind_Speed(mph)                0
# Precipitation(in)              0
# Weather_Condition          72753
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset              9550
# Civil_Twilight              9550
# Nautical_Twilight           9550
# Astronomical_Twilight       9550
# Duration                       0
# Month                          0
# dtype: int64

# %%
#dropping more columns that aren't needed (there are too many nulls and we have the start location)
new_df = new_df.drop(columns=['End_Lat', 'End_Lng'])

# %%
#renaming the columns
new_df = new_df.rename(columns={'Sunrise_Sunset':'Sunset'})

# %%
new_df.isnull().sum()
# Out:
# ID                           0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# Distance(mi)                 0
# Description                  5
# Street                    5875
# City                        72
# County                       0
# State                        0
# Zipcode                   1367
# Weather_Timestamp        55660
# Temperature(F)               0
# Wind_Chill(F)                0
# Humidity(%)                  0
# Pressure(in)                 0
# Visibility(mi)               0
# Wind_Speed(mph)              0
# Precipitation(in)            0
# Weather_Condition        72753
# Amenity                      0
# Bump                         0
# Crossing                     0
# Give_Way                     0
# Junction                     0
# No_Exit                      0
# Railway                      0
# Roundabout                   0
# Station                      0
# Stop                         0
# Traffic_Calming              0
# Traffic_Signal               0
# Turning_Loop                 0
# Sunset                    9550
# Civil_Twilight            9550
# Nautical_Twilight         9550
# Astronomical_Twilight     9550
# Duration                     0
# Month                        0
# dtype: int64

# %%
#seeing which words in weather condition has the most weights
data = new_df['Weather_Condition'].value_counts().to_dict()
wc = WordCloud(width = 900, height = 800, background_color ='white', min_font_size = 10).generate_from_frequencies(data)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
new_df['Weather_Condition'].unique()
# Out:
# array(['Clear', 'Partly Cloudy', 'Haze', 'Mostly Cloudy', 'Overcast',
#        'Scattered Clouds', 'Light Rain', nan, 'Mist', 'Smoke', 'Fog',
#        'Patches of Fog', 'Rain', 'Light Drizzle', 'Heavy Rain',
#        'Shallow Fog', 'Light Snow', 'Snow', 'Light Freezing Fog',
#        'Light Haze', 'Light Thunderstorms and Rain', 'Light Rain Showers',
#        'Thunderstorms and Rain', 'Fair', 'Cloudy', 'Volcanic Ash',
#        'Blowing Sand', 'Drizzle', 'Blowing Dust / Windy',
#        'Widespread Dust', 'Fair / Windy', 'Rain Showers',
#        'Mostly Cloudy / Windy', 'Light Rain / Windy', 'Hail',
#        'Heavy Drizzle', 'Showers in the Vicinity', 'Thunderstorm',
#        'Light Rain Shower', 'Light Rain with Thunder',
#        'Partly Cloudy / Windy', 'Thunder in the Vicinity', 'T-Storm',
#        'Heavy Thunderstorms and Rain', 'Thunder', 'Heavy T-Storm',
#        'Funnel Cloud', 'Heavy T-Storm / Windy', 'Light Freezing Rain',
#        'Heavy Snow', 'Light Freezing Drizzle', 'Light Ice Pellets',
#        'Ice Pellets', 'Snow Grains', 'Light Fog', 'Blowing Snow',
#        'Rain / Windy', 'Heavy Rain / Windy', 'Squalls', 'Thunder / Windy',
#        'N/A Precipitation', 'Cloudy / Windy', 'T-Storm / Windy',
#        'Smoke / Windy', 'Haze / Windy', 'Drizzle and Fog', 'Wintry Mix',
#        'Wintry Mix / Windy', 'Light Snow / Windy', 'Fog / Windy',
#        'Light Drizzle / Windy', 'Snow and Sleet', 'Light Sleet',
#        'Light Snow and Sleet', 'Light Freezing Rain / Windy',
#        'Thunder / Wintry Mix', 'Freezing Rain', 'Sleet',
#        'Heavy Freezing Rain / Windy', 'Heavy Freezing Rain',
#        'Snow / Windy', 'Heavy Snow / Windy', 'Light Sleet / Windy',
#        'Blowing Dust', 'Widespread Dust / Windy', 'Mist / Windy',
#        'Squalls / Windy', 'Duststorm', 'Thunder and Hail',
#        'Light Snow and Sleet / Windy', 'Drizzle / Windy',
#        'Blowing Snow / Windy', 'Rain Shower', 'Partial Fog',
#        'Snow and Sleet / Windy', 'Patches of Fog / Windy',
#        'Light Rain Shower / Windy', 'Rain and Sleet', 'Heavy Sleet',
#        'Light Snow Shower', 'Small Hail', 'Light Hail', 'Heavy Smoke',
#        'Sand', 'Heavy Thunderstorms with Small Hail',
#        'Light Thunderstorms and Snow', 'Light Blowing Snow',
#        'Heavy Rain Showers', 'Thunderstorms and Snow',
#        'Heavy Thunderstorms and Snow', 'Light Thunderstorm',
#        'Light Snow Showers', 'Dust Whirls', 'Rain Shower / Windy',
#        'Heavy Snow with Thunder', 'Freezing Rain / Windy',
#        'Freezing Drizzle', 'Snow and Thunder', 'Light Snow with Thunder',
#        'Shallow Fog / Windy', 'Sleet / Windy', 'Tornado',
#        'Heavy Sleet and Thunder', 'Sand / Windy',
#        'Heavy Rain Shower / Windy', 'Thunder / Wintry Mix / Windy',
#        'Heavy Rain Shower', 'Thunder and Hail / Windy'], dtype=object)

# %%
#replacing the values into 5 categories
#Rain, Snow, Low Visibility, Clear, Cloudy
new_df["Weather_Condition"] = new_df["Weather_Condition"].replace({'Clear':'Clear', 'Partly Cloudy':'Cloudy', 'Haze':'Low Visibility',
                                                                   'Mostly Cloudy':'Cloudy', 'Overcast':'Cloudy','Scattered Clouds':'Cloudy',
                                                                   'Light Rain':'Rain', 'Mist':'Low Visibility', 'Smoke':'Low Visibility',
                                                                   'Fog':'Low Visibility', 'Patches of Fog':'Low Visibility',
                                                                   'Rain':'Rain', 'Light Drizzle':'Rain', 'Heavy Rain':'Rain',
                                                                   'Shallow Fog':'Low Visibility', 'Light Snow':'Snow', 'Snow':'Snow',
                                                                   'Light Freezing Fog':'Low Visibility', 'Light Haze':'Low Visibility',
                                                                   'Light Thunderstorms and Rain':'Rain', 'Light Rain Showers':'Rain',
                                                                   'Thunderstorms and Rain':'Rain', 'Fair':'Clear', 'Cloudy':'Cloudy',
                                                                   'Volcanic Ash':'Low Visibility', 'Blowing Sand':'Low Visibility',
                                                                   'Drizzle':'Rain', 'Blowing Dust / Windy':'Low Visibility',
                                                                   'Widespread Dust':'Low Visibility', 'Fair / Windy':'Clear',
                                                                   'Rain Showers':'Rain', 'Mostly Cloudy / Windy':'Cloudy',
                                                                   'Light Rain / Windy':'Rain', 'Hail':'Snow', 'Heavy Drizzle':'Rain',
                                                                   'Showers in the Vicinity':'Rain', 'Thunderstorm':'Rain',
                                                                   'Light Rain Shower':'Rain', 'Light Rain with Thunder':'Rain',
                                                                   'Partly Cloudy / Windy':'Cloudy', 'Thunder in the Vicinity':'Rain',
                                                                   'T-Storm':'Rain', 'Heavy Thunderstorms and Rain':'Rain',
                                                                   'Thunder':'Rain', 'Heavy T-Storm':'Rain', 'Funnel Cloud':'Cloudy',
                                                                   'Heavy T-Storm / Windy':'Rain', 'Light Freezing Rain':'Rain',
                                                                   'Heavy Snow':'Snow', 'Light Freezing Drizzle':'Rain',
                                                                   'Light Ice Pellets':'Snow', 'Ice Pellets':'Snow',
                                                                   'Snow Grains':'Snow', 'Light Fog':'Low Visibility',
                                                                   'Blowing Snow':'Snow', 'Rain / Windy':'Rain',
                                                                   'Heavy Rain / Windy':'Rain', 'Squalls':'Rain', 'Thunder / Windy':'Rain',
                                                                   'N/A Precipitation':'Clear', 'Cloudy / Windy':'Cloudy',
                                                                   'T-Storm / Windy':'Rain', 'Smoke / Windy':'Low Visibility',
                                                                   'Haze / Windy':'Low Visibility', 'Drizzle and Fog':'Low Visibility',
                                                                   'Wintry Mix':'Snow', 'Wintry Mix / Windy':'Snow',
                                                                   'Light Snow / Windy':'Snow', 'Fog / Windy':'Low Visibility',
                                                                   'Light Drizzle / Windy':'Rain', 'Snow and Sleet':'Snow',
                                                                   'Light Sleet':'Snow', 'Light Snow and Sleet':'Snow',
                                                                   'Light Freezing Rain / Windy':'Rain', 'Thunder / Wintry Mix':'Snow',
                                                                   'Sleet':'Snow', 'Freezing Rain':'Rain',
                                                                   'Heavy Freezing Rain / Windy':'Rain', 'Heavy Freezing Rain':'Rain',
                                                                   'Snow / Windy':'Snow', 'Heavy Snow / Windy':'Snow',
                                                                   'Light Sleet / Windy':'Snow', 'Blowing Dust':'Low Visibility',
                                                                   'Widespread Dust / Windy':'Low Visibility',
                                                                   'Mist / Windy':'Low Visibility', 'Squalls / Windy':'Rain',
                                                                   'Duststorm':'Low Visibility', 'Thunder and Hail':'Snow',
                                                                   'Light Snow and Sleet / Windy':'Snow', 'Drizzle / Windy':'Rain',
                                                                   'Blowing Snow / Windy':'Snow', 'Rain Shower':'Rain',
                                                                   'Partial Fog':'Low Visibility', 'Snow and Sleet / Windy':'Snow',
                                                                   'Patches of Fog / Windy':'Low Visibility',
                                                                   'Light Rain Shower / Windy':'Rain', 'Heavy Sleet':'Snow',
                                                                   'Light Snow Shower':'Snow', 'Small Hail':'Snow', 'Light Hail':'Snow',
                                                                   'Heavy Smoke':'Low Visibility', 'Sand':'Low Visibility',
                                                                   'Heavy Thunderstorms with Small Hail':'Snow',
                                                                   'Light Thunderstorms and Snow':'Snow', 'Light Blowing Snow':'Snow',
                                                                   'Heavy Rain Showers':'Rain', 'Thunderstorms and Snow':'Snow',
                                                                   'Heavy Thunderstorms and Snow':'Snow', 'Light Thunderstorm':'Rain',
                                                                   'Light Snow Showers':'Snow', 'Dust Whirls':'Low Visibility',
                                                                   'Rain Shower / Windy':'Rain', 'Heavy Snow with Thunder':'Snow',
                                                                   'Freezing Drizzle':'Rain', 'Snow and Thunder':'Snow',
                                                                   'Shallow Fog / Windy':'Low Visibility', 'Sleet / Windy':'Snow',
                                                                   'Light Snow with Thunder':'Snow', 'Tornado':'Cloudy',
                                                                   'Heavy Sleet and Thunder':'Snow', 'Sand / Windy':'Low Visibility',
                                                                   'Heavy Rain Shower / Windy':'Rain', 'Freezing Rain / Windy':'Rain',
                                                                   'Thunder / Wintry Mix / Windy':'Snow', 'Heavy Rain Shower':'Rain',
                                                                   'Thunder and Hail / Windy':'Snow', 'Rain and Sleet':'Rain'})

# %%
new_df
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 728          A-729         3 2016-06-21 10:34:40 2016-06-21 11:04:40
# 729          A-730         3 2016-06-21 10:30:16 2016-06-21 11:16:39
# 730          A-731         2 2016-06-21 10:49:14 2016-06-21 11:19:14
# 731          A-732         3 2016-06-21 10:41:42 2016-06-21 11:11:42
# 732          A-733         2 2016-06-21 10:16:26 2016-06-21 11:04:16
# ...            ...       ...                 ...                 ...
# 7728389  A-7777757         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# 7728390  A-7777758         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# 7728391  A-7777759         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# 7728392  A-7777760         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# 7728393  A-7777761         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng  Distance(mi)  \
# 728      38.085300 -122.233017         0.000
# 729      37.631813 -122.084167         0.000
# 730      37.896564 -122.070717         0.000
# 731      37.334255 -122.032471         0.000
# 732      37.250729 -121.910713         0.000
# ...            ...         ...           ...
# 7728389  34.002480 -117.379360         0.543
# 7728390  32.766960 -117.148060         0.338
# 7728391  33.775450 -117.847790         0.561
# 7728392  33.992460 -118.403020         0.772
# 7728393  34.133930 -117.230920         0.537
#
#                                                Description  \
# 728      Right hand shoulder blocked due to accident on...
# 729      Accident on I-880 Northbound at Exit 26 Tennys...
# 730      Right lane blocked due to accident on CA-24 We...
# 731      #4 &amp; HOV lane blocked due to accident on I...
# 732      Right hand shoulder blocked due to accident on...
# ...                                                    ...
# 7728389                           At Market St - Accident.
# 7728390    At Camino Del Rio/Mission Center Rd - Accident.
# 7728391  At Glassell St/Grand Ave - Accident. in the ri...
# 7728392     At CA-90/Marina Fwy/Jefferson Blvd - Accident.
# 7728393              At Highland Ave/Arden Ave - Accident.
#
#                       Street          City          County State Zipcode  \
# 728              Magazine St       Vallejo          Solano    CA   94591
# 729                  I-880 N       Hayward         Alameda    CA   94544
# 730                  I-680 N  Walnut Creek    Contra Costa    CA   94595
# 731           N De Anza Blvd     Cupertino     Santa Clara    CA   95014
# 732      Norman Y Mineta Hwy      San Jose     Santa Clara    CA   95118
# ...                      ...           ...             ...   ...     ...
# 7728389         Pomona Fwy E     Riverside       Riverside    CA   92501
# 7728390                I-8 W     San Diego       San Diego    CA   92108
# 7728391     Garden Grove Fwy        Orange          Orange    CA   92866
# 7728392      San Diego Fwy S   Culver City     Los Angeles    CA   90230
# 7728393             CA-210 W      Highland  San Bernardino    CA   92346
#
#           Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 728     2016-06-21 10:54:00            75.0       64.73455         48.0
# 729     2016-06-21 10:54:00            75.0       64.73455         48.0
# 730     2016-06-21 10:53:00            82.9       64.73455         31.0
# 731     2016-06-21 10:56:00            75.9       64.73455         48.0
# 732     2016-06-21 09:50:00            75.2       64.73455         41.0
# ...                     ...             ...            ...          ...
# 7728389 2019-08-23 17:53:00            86.0       86.00000         40.0
# 7728390 2019-08-23 18:53:00            70.0       70.00000         73.0
# 7728391 2019-08-23 18:53:00            73.0       73.00000         64.0
# 7728392 2019-08-23 18:51:00            71.0       71.00000         81.0
# 7728393 2019-08-23 20:50:00            79.0       79.00000         47.0
#
#          Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  \
# 728             30.00            10.0        24.577115           0.008342
# 729             30.06            10.0        24.577115           0.008342
# 730             29.97            10.0        24.577115           0.008342
# 731             30.04            10.0        24.577115           0.008342
# 732             30.06            10.0        24.577115           0.008342
# ...               ...             ...              ...                ...
# 7728389         28.92            10.0        24.577115           0.000000
# 7728390         29.39            10.0        24.577115           0.000000
# 7728391         29.74            10.0        24.577115           0.000000
# 7728392         29.62            10.0        24.577115           0.000000
# 7728393         28.63             7.0        24.577115           0.000000
#
#         Weather_Condition  Amenity   Bump  Crossing  Give_Way  Junction  \
# 728                 Clear    False  False     False     False     False
# 729                 Clear    False  False     False     False     False
# 730                 Clear    False  False     False     False     False
# 731                 Clear    False  False     False     False     False
# 732                 Clear    False  False     False     False     False
# ...                   ...      ...    ...       ...       ...       ...
# 7728389             Clear    False  False     False     False     False
# 7728390             Clear    False  False     False     False     False
# 7728391            Cloudy    False  False     False     False      True
# 7728392             Clear    False  False     False     False     False
# 7728393             Clear    False  False     False     False     False
#
#          No_Exit  Railway  Roundabout  Station   Stop  Traffic_Calming  \
# 728        False    False       False    False  False            False
# 729        False    False       False    False  False            False
# 730        False    False       False    False  False            False
# 731        False    False       False    False  False            False
# 732        False    False       False    False  False            False
# ...          ...      ...         ...      ...    ...              ...
# 7728389    False    False       False    False  False            False
# 7728390    False    False       False    False  False            False
# 7728391    False    False       False    False  False            False
# 7728392    False    False       False    False  False            False
# 7728393    False    False       False    False  False            False
#
#          Traffic_Signal  Turning_Loop Sunset Civil_Twilight Nautical_Twilight  \
# 728               False         False    Day            Day               Day
# 729               False         False    Day            Day               Day
# 730               False         False    Day            Day               Day
# 731               False         False    Day            Day               Day
# 732               False         False    Day            Day               Day
# ...                 ...           ...    ...            ...               ...
# 7728389           False         False    Day            Day               Day
# 7728390           False         False    Day            Day               Day
# 7728391           False         False    Day            Day               Day
# 7728392           False         False    Day            Day               Day
# 7728393           False         False    Day            Day               Day
#
#         Astronomical_Twilight        Duration  Month
# 728                       Day 0 days 00:30:00      6
# 729                       Day 0 days 00:46:23      6
# 730                       Day 0 days 00:30:00      6
# 731                       Day 0 days 00:30:00      6
# 732                       Day 0 days 00:47:50      6
# ...                       ...             ...    ...
# 7728389                   Day 0 days 00:28:36      8
# 7728390                   Day 0 days 00:26:53      8
# 7728391                   Day 0 days 00:28:28      8
# 7728392                   Day 0 days 00:29:21      8
# 7728393                   Day 0 days 00:29:25      8
#
# [4273178 rows x 41 columns]

# %%
#since we have a large enough dataset, we are dropping the null values in these columns
new_df.dropna(subset=['Weather_Condition', 'Sunset', 'Civil_Twilight',
                      'Nautical_Twilight', 'Astronomical_Twilight'], inplace=True)

# %%
#making sure there's no null values in the weather_condition column
new_df['Weather_Condition'].isna().sum()
# Out:
# 0

# %%
new_df.isnull().sum()
# Out:
# ID                          0
# Severity                    0
# Start_Time                  0
# End_Time                    0
# Start_Lat                   0
# Start_Lng                   0
# Distance(mi)                0
# Description                 5
# Street                   5736
# City                        0
# County                      0
# State                       0
# Zipcode                     0
# Weather_Timestamp           0
# Temperature(F)              0
# Wind_Chill(F)               0
# Humidity(%)                 0
# Pressure(in)                0
# Visibility(mi)              0
# Wind_Speed(mph)             0
# Precipitation(in)           0
# Weather_Condition           0
# Amenity                     0
# Bump                        0
# Crossing                    0
# Give_Way                    0
# Junction                    0
# No_Exit                     0
# Railway                     0
# Roundabout                  0
# Station                     0
# Stop                        0
# Traffic_Calming             0
# Traffic_Signal              0
# Turning_Loop                0
# Sunset                      0
# Civil_Twilight              0
# Nautical_Twilight           0
# Astronomical_Twilight       0
# Duration                    0
# Month                       0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4191743 entries, 728 to 7728393
# Data columns (total 41 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               datetime64[ns]
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   Distance(mi)           float64
#  7   Description            object
#  8   Street                 object
#  9   City                   object
#  10  County                 object
#  11  State                  object
#  12  Zipcode                object
#  13  Weather_Timestamp      datetime64[ns]
#  14  Temperature(F)         float64
#  15  Wind_Chill(F)          float64
#  16  Humidity(%)            float64
#  17  Pressure(in)           float64
#  18  Visibility(mi)         float64
#  19  Wind_Speed(mph)        float64
#  20  Precipitation(in)      float64
#  21  Weather_Condition      object
#  22  Amenity                bool
#  23  Bump                   bool
#  24  Crossing               bool
#  25  Give_Way               bool
#  26  Junction               bool
#  27  No_Exit                bool
#  28  Railway                bool
#  29  Roundabout             bool
#  30  Station                bool
#  31  Stop                   bool
#  32  Traffic_Calming        bool
#  33  Traffic_Signal         bool
#  34  Turning_Loop           bool
#  35  Sunset                 object
#  36  Civil_Twilight         object
#  37  Nautical_Twilight      object
#  38  Astronomical_Twilight  object
#  39  Duration               timedelta64[ns]
#  40  Month                  int32
# dtypes: bool(13), datetime64[ns](3), float64(10), int32(1), int64(1), object(12), timedelta64[ns](1)
# memory usage: 963.4+ MB

# %% [markdown]
# ### Number of Accidents throughout the Years in America

# %%
ax = sns.histplot(data=new_df, x=new_df['Start_Time'], bins='auto')
ax.set_title('Number of Accidents per Year in the USA')
ax.set_xlabel('Year')
ax.set_ylabel('# of accididents')
plt.show()

# %% [markdown]
# The drop in mid-2020 could be explained by the COVID-19 shutdown, during which many people stayed indoors, resulting in fewer cars on the roads.

# %%
#seeing which words in weather condition has the most weights AFTER binning them to 5 categories
data = new_df['Weather_Condition'].value_counts().to_dict()
wc = WordCloud(width = 900, height = 800, background_color ='white', min_font_size = 10).generate_from_frequencies(data)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Target variable to binary classification

# %%
new_df['Severity'].value_counts()
# Out:
# Severity
# 2    3475279
# 3     627072
# 4      55826
# 1      33566
# Name: count, dtype: int64

# %%
#creating a new column called Binary_Severity and grouping the severity classes to have a binary classification
#Not Severe = 0
#Severe = 1
new_df['Binary_Severity'] = new_df['Severity'].replace({1:0, 2:0, 3:1, 4:1})

# %%
#grouping the not severe by states
severity_count_0 = new_df[new_df['Binary_Severity'] == 0].groupby('State').size()
severity_count_0.sort_values(ascending=False)
# Out:
# State
# CA    1421394
# FL     750332
# TX     448745
# SC     329700
# NC     294010
# NY     264664
# dtype: int64

# %%
#seeing how many severe we have by states
severity_count_1 = new_df[new_df['Binary_Severity'] == 1].groupby('State').size()
severity_count_1.sort_values(ascending=False)
# Out:
# State
# CA    279460
# TX    124497
# FL    115520
# NY     79937
# SC     44762
# NC     38722
# dtype: int64

# %%
new_df['Binary_Severity'].value_counts()
# Out:
# Binary_Severity
# 0    3508845
# 1     682898
# Name: count, dtype: int64

# %% [markdown]
# ### Presence of a Point of Interest (POI)

# %%
columns_to_plot = ["Amenity","Bump","Crossing","Give_Way","Junction","No_Exit","Railway",
                   "Roundabout","Station","Stop","Traffic_Calming","Traffic_Signal","Turning_Loop"]

# Assume your data is stored in a DataFrame called 'df'
# You can create a new DataFrame with just the binary columns
binary_df = new_df[columns_to_plot]

# Calculate the frequency of each binary value (0 or 1) in each column
binary_counts = binary_df.sum()

#plot
plt.bar(binary_counts.index, binary_counts.values)
plt.xlabel("POI")
plt.ylabel("Total Number of Accidents")
plt.title("Total Number of Accidents by POI")
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %% [markdown]
# ### Showing the individual percentages of each POI's presence in the accidents

# %%
# column names we want to plot
columns_to_plot = ["Amenity","Bump","Crossing","Give_Way","Junction","No_Exit","Railway",
                   "Roundabout","Station","Stop","Traffic_Calming","Traffic_Signal","Turning_Loop"]

# Create a plot with multiple subplots
fig, axes = plt.subplots(len(columns_to_plot), 1, figsize=(8, 4 * len(columns_to_plot)))

# Iterate through the columns and create a pie chart for each one
for i, col in enumerate(columns_to_plot):
    # Get the value counts for the column
    value_counts = new_df[col].value_counts()

    # Create a pie chart for the column
    axes[i].pie(value_counts, labels=value_counts.index, autopct='%1.1f%%') #decided to use a pie chart since we have only 2 variables
    axes[i].set_title(col)

# Adjust the layout of the subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Traffic Signal appear to have a larger presence in these accidents compared to the other POIs. Let's investigate further into that column.

# %%
#plotting the severity class to the period of day columns
fig, axes = plt.subplots(4, 3, figsize=(16, 16))

# ax = sns.countplot(data=new_df, x=new_df['Severity'], hue=new_df['Sunset'])
ax = sns.countplot(data=new_df, x=new_df["Amenity"], hue=new_df['Severity'], ax=axes[0,0])
ax = sns.countplot(data=new_df, x=new_df["Bump"], hue=new_df['Severity'], ax=axes[0,1])
ax = sns.countplot(data=new_df, x=new_df["Crossing"], hue=new_df['Severity'], ax=axes[0,2])
ax = sns.countplot(data=new_df, x=new_df["Give_Way"], hue=new_df['Severity'], ax=axes[1,0])
ax = sns.countplot(data=new_df, x=new_df["Junction"], hue=new_df['Severity'], ax=axes[1,1])
ax = sns.countplot(data=new_df, x=new_df["No_Exit"], hue=new_df['Severity'], ax=axes[1,2])
ax = sns.countplot(data=new_df, x=new_df["Railway"], hue=new_df['Severity'], ax=axes[2,0])
ax = sns.countplot(data=new_df, x=new_df["Roundabout"], hue=new_df['Severity'], ax=axes[2,1])
ax = sns.countplot(data=new_df, x=new_df["Station"], hue=new_df['Severity'], ax=axes[2,2])
ax = sns.countplot(data=new_df, x=new_df["Stop"], hue=new_df['Severity'], ax=axes[3,0])
ax = sns.countplot(data=new_df, x=new_df["Traffic_Calming"], hue=new_df['Severity'], ax=axes[3,1])
ax = sns.countplot(data=new_df, x=new_df["Traffic_Signal"], hue=new_df['Severity'], ax=axes[3,2])
plt.tight_layout()

plt.figure(figsize=(4, 4))
ax = sns.countplot(data=new_df, x=new_df["Turning_Loop"], hue=new_df['Severity'])

plt.grid(False)
plt.show()

# %%
new_df['Traffic_Signal'].value_counts()
# Out:
# Traffic_Signal
# False    3568075
# True      623668
# Name: count, dtype: int64

# %%
new_df[new_df['Traffic_Signal'] == 1].sort_values(by='Severity', ascending=False)
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 4401306  A-4434614         4 2022-02-23 20:50:18 2022-02-23 23:59:00
# 3811505  A-3840069         4 2022-09-24 21:21:00 2022-09-25 06:30:00
# 7538307  A-7587675         4 2018-05-29 02:03:09 2018-05-29 08:03:09
# 6972579  A-7021892         4 2020-05-11 08:34:19 2020-05-11 09:24:17
# 6972571  A-7021884         4 2020-05-11 04:59:53 2020-05-11 05:29:53
# ...            ...       ...                 ...                 ...
# 7091920  A-7141259         1 2020-03-27 17:31:32 2020-03-27 18:16:32
# 7091919  A-7141258         1 2020-03-27 18:00:27 2020-03-27 18:45:27
# 7091918  A-7141257         1 2020-03-27 14:59:13 2020-03-27 16:19:11
# 7091917  A-7141256         1 2020-03-27 14:26:43 2020-03-27 15:01:41
# 7083002  A-7132340         1 2020-03-23 09:21:21 2020-03-23 09:51:21
#
#          Start_Lat   Start_Lng  Distance(mi)  \
# 4401306  36.330151 -119.293453         0.063
# 3811505  32.836554  -96.959436         0.073
# 7538307  30.225000  -97.703430         0.092
# 6972579  35.164910  -80.876070         0.847
# 6972571  35.176510  -80.875880         0.802
# ...            ...         ...           ...
# 7091920  31.759060 -106.355570         0.000
# 7091919  31.825690 -106.444980         0.000
# 7091918  31.776380 -106.268400         0.000
# 7091917  31.762200 -106.395100         0.000
# 7083002  31.785540 -106.356050         0.000
#
#                                                Description           Street  \
# 4401306  CA-63 is closed from W Main St (S Locust St) t...      N Locust St
# 3811505  Incident on TX-183 EB near TX-356 Road closed....    W Airport Fwy
# 7538307  Closed at Clubview Ave - Road closed due to ac...    Montopolis Dr
# 6972579  Closed at E Arrowood Rd/Starbrook Dr - Road cl...       South Blvd
# 6972571                   At Tyvola Rd - Serious accident.    E Woodlawn Rd
# ...                                                    ...              ...
# 7091920         At FM-2316/McRae Blvd/Exit 28A - Accident.       McRae Blvd
# 7091919                 At TX-478-LOOP/Dyer St - Accident.          Dyer St
# 7091918         At TX-375-LOOP/Joe Battle Blvd - Accident.  Joe Battle Blvd
# 7091917                       At Trowbridge Dr - Accident.        N Loop Dr
# 7083002                         At Montwood Dr - Accident.       McRae Blvd
#
#               City       County State     Zipcode   Weather_Timestamp  \
# 4401306    Visalia       Tulare    CA       93291 2022-02-23 20:56:00
# 3811505     Irving       Dallas    TX       75062 2022-09-24 20:53:00
# 7538307     Austin       Travis    TX       78741 2018-05-29 01:53:00
# 6972579  Charlotte  Mecklenburg    NC       28217 2020-05-11 08:52:00
# 6972571  Charlotte  Mecklenburg    NC       28209 2020-05-11 04:52:00
# ...            ...          ...   ...         ...                 ...
# 7091920    El Paso      El Paso    TX       79925 2020-03-27 17:42:00
# 7091919    El Paso      El Paso    TX       79930 2020-03-27 17:42:00
# 7091918    El Paso      El Paso    TX       79938 2020-03-27 14:46:00
# 7091917    El Paso      El Paso    TX       79905 2020-03-27 14:46:00
# 7083002    El Paso      El Paso    TX  79925-4128 2020-03-23 09:44:00
#
#          Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 4401306            39.0       36.00000         86.0         29.88
# 3811505            83.0       83.00000         42.0         29.27
# 7538307            73.9       64.73455         85.0         29.75
# 6972579            55.0       55.00000         43.0         29.31
# 6972571            50.0       50.00000         71.0         29.23
# ...                 ...            ...          ...           ...
# 7091920            72.0       72.00000         11.0         25.85
# 7091919            72.0       72.00000         11.0         25.85
# 7091918            75.0       75.00000         14.0         25.84
# 7091917            75.0       75.00000         14.0         25.84
# 7083002            61.0       61.00000         27.0         26.16
#
#          Visibility(mi)  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# 4401306            10.0        24.577115           0.000000             Clear
# 3811505            10.0        24.577115           0.000000             Clear
# 7538307            10.0        24.577115           0.008342             Clear
# 6972579            10.0        24.577115           0.000000             Clear
# 6972571            10.0        24.577115           0.000000             Clear
# ...                 ...              ...                ...               ...
# 7091920             4.0        24.577115           0.008342    Low Visibility
# 7091919             4.0        24.577115           0.008342    Low Visibility
# 7091918             4.0        24.577115           0.008342    Low Visibility
# 7091917             4.0        24.577115           0.008342    Low Visibility
# 7083002            10.0        24.577115           0.008342            Cloudy
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 4401306    False  False     False     False     False    False    False
# 3811505    False  False      True     False     False    False    False
# 7538307     True  False     False     False     False    False    False
# 6972579    False  False      True     False     False    False    False
# 6972571    False  False      True     False     False    False    False
# ...          ...    ...       ...       ...       ...      ...      ...
# 7091920    False  False     False     False     False    False    False
# 7091919    False  False     False     False     False    False    False
# 7091918    False  False     False     False     False    False    False
# 7091917    False  False     False     False     False    False    False
# 7083002    False  False     False     False     False    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 4401306       False    False  False            False            True
# 3811505       False    False  False            False            True
# 7538307       False    False  False            False            True
# 6972579       False    False  False            False            True
# 6972571       False    False  False            False            True
# ...             ...      ...    ...              ...             ...
# 7091920       False    False  False            False            True
# 7091919       False    False  False            False            True
# 7091918       False    False  False            False            True
# 7091917       False    False  False            False            True
# 7083002       False    False  False            False            True
#
#          Turning_Loop Sunset Civil_Twilight Nautical_Twilight  \
# 4401306         False  Night          Night             Night
# 3811505         False  Night          Night             Night
# 7538307         False  Night          Night             Night
# 6972579         False    Day            Day               Day
# 6972571         False  Night          Night             Night
# ...               ...    ...            ...               ...
# 7091920         False    Day            Day               Day
# 7091919         False    Day            Day               Day
# 7091918         False    Day            Day               Day
# 7091917         False    Day            Day               Day
# 7083002         False    Day            Day               Day
#
#         Astronomical_Twilight        Duration  Month  Binary_Severity
# 4401306                 Night 0 days 03:08:42      2                1
# 3811505                 Night 0 days 09:09:00      9                1
# 7538307                 Night 0 days 06:00:00      5                1
# 6972579                   Day 0 days 00:49:58      5                1
# 6972571                   Day 0 days 00:30:00      5                1
# ...                       ...             ...    ...              ...
# 7091920                   Day 0 days 00:45:00      3                0
# 7091919                   Day 0 days 00:45:00      3                0
# 7091918                   Day 0 days 01:19:58      3                0
# 7091917                   Day 0 days 00:34:58      3                0
# 7083002                   Day 0 days 00:30:00      3                0
#
# [623668 rows x 42 columns]

# %%
#replacing the boolean values to binary number
new_df["Amenity"] = new_df["Amenity"].replace({False:0, True:1})
new_df["Bump"] = new_df["Bump"].replace({False:0, True:1})
new_df["Crossing"] = new_df["Crossing"].replace({False:0, True:1})
new_df["Give_Way"] = new_df["Give_Way"].replace({False:0, True:1})
new_df["Junction"] = new_df["Junction"].replace({False:0, True:1})
new_df["No_Exit"] = new_df["No_Exit"].replace({False:0, True:1})
new_df["Railway"] = new_df["Railway"].replace({False:0, True:1})
new_df["Roundabout"] = new_df["Roundabout"].replace({False:0, True:1})
new_df["Station"] = new_df["Station"].replace({False:0, True:1})
new_df["Stop"] = new_df["Stop"].replace({False:0, True:1})
new_df["Traffic_Calming"] = new_df["Traffic_Calming"].replace({False:0, True:1})
new_df["Traffic_Signal"] = new_df["Traffic_Signal"].replace({False:0, True:1})
new_df["Turning_Loop"] = new_df["Turning_Loop"].replace({False:0, True:1})

# %% [markdown]
# ### Period of Day

# %%
# column names we want to plot
columns_to_plot = ["Sunset", "Civil_Twilight", "Nautical_Twilight", "Astronomical_Twilight"]

# Create a plot with multiple subplots
fig, axes = plt.subplots(len(columns_to_plot), 1, figsize=(8, 4 * len(columns_to_plot)))

# Iterate through the columns and create a pie chart for each one
for i, col in enumerate(columns_to_plot):
    # Get the value counts for the column
    value_counts = new_df[col].value_counts()

    # Create a pie chart for the column
    axes[i].pie(value_counts, labels=value_counts.index, autopct='%1.1f%%') #decided to use a pie chart. Interpretable with only 2 variables
    axes[i].set_title(col)

# Adjust the layout of the subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
#plotting the severity class to the period of day columns
fig, axes = plt.subplots(2, 2, figsize=(8, 10))

# ax = sns.countplot(data=new_df, x=new_df['Severity'], hue=new_df['Sunset'])
ax = sns.countplot(data=new_df, x=new_df['Sunset'], hue=new_df['Binary_Severity'], ax=axes[0,0])
ax = sns.countplot(data=new_df, x=new_df['Civil_Twilight'], hue=new_df['Severity'], ax=axes[0,1])
ax = sns.countplot(data=new_df, x=new_df['Nautical_Twilight'], hue=new_df['Severity'], ax=axes[1,0])
ax = sns.countplot(data=new_df, x=new_df['Astronomical_Twilight'], hue=new_df['Severity'], ax=axes[1,1])

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
# replacing the values so it's numeric
new_df['Sunset'] = new_df['Sunset'].replace({'Day':0, 'Night':1})
new_df['Civil_Twilight'] = new_df['Civil_Twilight'].replace({'Day':0, 'Night':1})
new_df['Nautical_Twilight'] = new_df['Nautical_Twilight'].replace({'Day':0, 'Night':1})
new_df['Astronomical_Twilight'] = new_df['Astronomical_Twilight'].replace({'Day':0, 'Night':1})

# %% [markdown]
# ### Weather Related

# %%
new_df.describe()
# Out:
#            Severity                     Start_Time  \
# count  4.191743e+06                        4191743
# mean   2.168225e+00  2020-06-05 04:10:51.554892544
# min    1.000000e+00            2016-03-22 17:44:13
# 25%    2.000000e+00            2018-11-20 10:06:59
# 50%    2.000000e+00            2020-11-23 00:59:21
# 75%    2.000000e+00            2022-01-25 07:56:00
# max    4.000000e+00            2023-03-31 23:25:30
# std    4.272905e-01                            NaN
#
#                             End_Time     Start_Lat     Start_Lng  \
# count                        4191743  4.191743e+06  4.191743e+06
# mean   2020-06-05 06:21:43.661026560  3.367794e+01 -9.830701e+01
# min              2016-03-22 22:05:41  2.455480e+01 -1.243750e+02
# 25%       2018-11-20 10:48:45.500000  3.024761e+01 -1.182231e+02
# 50%              2020-11-23 03:51:00  3.402556e+01 -9.558344e+01
# 75%       2022-01-25 09:18:34.500000  3.611043e+01 -8.083732e+01
# max              2023-03-31 23:58:00  4.500189e+01 -7.211488e+01
# std                              NaN  4.288984e+00  1.852345e+01
#
#        Distance(mi)              Weather_Timestamp  Temperature(F)  \
# count  4.191743e+06                        4191743    4.191743e+06
# mean   4.542848e-01  2020-06-05 04:11:46.107773696    6.630963e+01
# min    0.000000e+00            2016-03-22 17:50:00   -5.800000e+01
# 25%    0.000000e+00            2018-11-20 09:55:00    5.590000e+01
# 50%    2.000000e-02            2020-11-23 00:53:00    6.710000e+01
# 75%    3.360000e-01            2022-01-25 07:53:00    7.800000e+01
# max    3.336300e+02            2023-03-31 23:53:00    2.070000e+02
# std    1.419175e+00                            NaN    1.557685e+01
#
#        Wind_Chill(F)   Humidity(%)  Pressure(in)  Visibility(mi)  \
# count   4.191743e+06  4.191743e+06  4.191743e+06    4.191743e+06
# mean    6.472920e+01  6.408483e+01  2.973468e+01    9.187779e+00
# min    -8.000000e+01  1.000000e+00  0.000000e+00    0.000000e+00
# 25%     5.900000e+01  4.800000e+01  2.962000e+01    1.000000e+01
# 50%     6.473455e+01  6.600000e+01  2.990000e+01    1.000000e+01
# 75%     7.400000e+01  8.300000e+01  3.004000e+01    1.000000e+01
# max     2.070000e+02  1.000000e+02  5.863000e+01    1.400000e+02
# std     1.498851e+01  2.262210e+01  6.134453e-01    2.313711e+00
#
#        Wind_Speed(mph)  Precipitation(in)                   Duration  \
# count     4.191743e+06       4.191743e+06                    4191743
# mean      2.457712e+01       8.238043e-03  0 days 02:10:52.106134846
# min       1.001000e+01       0.000000e+00            0 days 00:01:55
# 25%       2.457712e+01       0.000000e+00            0 days 00:33:21
# 50%       2.457712e+01       0.000000e+00            0 days 01:15:00
# 75%       2.457712e+01       8.342249e-03            0 days 02:06:36
# max       1.087000e+02       2.400000e+01         1553 days 01:25:45
# std       1.171786e-01       1.033340e-01  2 days 16:38:37.523137164
#
#               Month  Binary_Severity
# count  4.191743e+06     4.191743e+06
# mean   6.687164e+00     1.629150e-01
# min    1.000000e+00     0.000000e+00
# 25%    3.000000e+00     0.000000e+00
# 50%    7.000000e+00     0.000000e+00
# 75%    1.000000e+01     0.000000e+00
# max    1.200000e+01     1.000000e+00
# std    3.628804e+00     3.692882e-01

# %%
#207(F) temperature?
new_df[new_df['Temperature(F)'] == 2.070000e+02]
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 4208142  A-4239885         2 2023-02-22 19:24:00 2023-02-22 21:32:35
# 4546366  A-4580836         2 2023-02-22 20:10:00 2023-02-23 00:01:38
# 5029338  A-5067455         4 2023-02-22 19:30:00 2023-02-23 00:00:53
#
#          Start_Lat   Start_Lng  Distance(mi)  \
# 4208142  34.066720 -117.238034         0.021
# 4546366  34.228800 -117.301024         0.417
# 5029338  34.228728 -117.251234         0.543
#
#                                                Description  \
# 4208142  Accident on I-10 W from California St (I-10) t...
# 4546366  Accident on CA-18 from N Sierra Way (N Waterma...
# 5029338  CA-189 is closed from CA-18/Lake Gregory Dr (C...
#
#                         Street            City          County State Zipcode  \
# 4208142                 I-10 W        Redlands  San Bernardino    CA   92374
# 4546366   Rim of the World Hwy  San Bernardino  San Bernardino    CA   92404
# 5029338        Lake Gregory Dr       Crestline  San Bernardino    CA   92325
#
#           Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 4208142 2023-02-22 19:54:00           207.0          207.0    64.096165
# 4546366 2023-02-22 19:54:00           207.0          207.0    64.096165
# 5029338 2023-02-22 19:54:00           207.0          207.0    64.096165
#
#          Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  \
# 4208142         28.66             7.0        24.577115                0.0
# 4546366         28.66             7.0        24.577115                0.0
# 5029338         28.66             7.0        24.577115                0.0
#
#         Weather_Condition  Amenity   Bump  Crossing  Give_Way  Junction  \
# 4208142            Cloudy    False  False     False     False      True
# 4546366            Cloudy    False  False     False     False     False
# 5029338            Cloudy    False  False     False     False     False
#
#          No_Exit  Railway  Roundabout  Station   Stop  Traffic_Calming  \
# 4208142    False    False       False    False  False            False
# 4546366    False    False       False    False  False            False
# 5029338    False    False       False    False  False            False
#
#          Traffic_Signal  Turning_Loop Sunset Civil_Twilight Nautical_Twilight  \
# 4208142           False         False  Night          Night             Night
# 4546366           False         False  Night          Night             Night
# 5029338           False         False  Night          Night             Night
#
#         Astronomical_Twilight        Duration  Month  Binary_Severity
# 4208142                 Night 0 days 02:08:35      2                0
# 4546366                 Night 0 days 03:51:38      2                0
# 5029338                 Night 0 days 04:30:53      2                1

# %%
new_df['Temperature(F)'].value_counts()
# Out:
# Temperature(F)
#  77.0     115997
#  73.0     107569
#  68.0     104967
#  75.0     101793
#  72.0     101241
#            ...
# -29.9          1
#  132.8         1
#  143.6         1
# -7.6           1
#  13.5          1
# Name: count, Length: 687, dtype: int64

# %%
fig, axes = plt.subplots(3, 2, figsize=(16, 16))

sns.histplot(new_df['Temperature(F)'].values, bins='auto', kde=True, log_scale=False, ax=axes[0,0])
sns.histplot(new_df['Wind_Chill(F)'].values, bins='auto', kde=True, log_scale=False, ax=axes[0,1])
sns.histplot(new_df['Humidity(%)'].values, bins='auto', kde=True, log_scale=False, ax=axes[1,0])
sns.histplot(new_df['Pressure(in)'].values, bins='auto', kde=True, log_scale=False, ax=axes[1,1])
sns.histplot(df['Visibility(mi)'].values, bins= 5, kde=True, log_scale=False, ax=axes[2,0])
sns.histplot(new_df['Wind_Speed(mph)'].values, bins='auto', kde=True, log_scale=False, ax=axes[2,1])
plt.tight_layout()

plt.figure(figsize=(6, 4))
sns.histplot(new_df['Precipitation(in)'].values, bins='auto', kde=True, log_scale=False)

plt.show()

# %%
#plotting the severity class to the period of day columns
fig, axes = plt.subplots(3, 2, figsize=(16, 16))

# ax = sns.countplot(data=new_df, x=new_df['Severity'], hue=new_df['Sunset'])
ax = sns.countplot(data=new_df, x=new_df['Temperature(F)'], hue=new_df['Binary_Severity'], ax=axes[0,0])
ax = sns.countplot(data=new_df, x=new_df['Wind_Chill(F)'].values, hue=new_df['Binary_Severity'], ax=axes[0,1])
ax = sns.countplot(data=new_df, x=new_df['Humidity(%)'].values, hue=new_df['Binary_Severity'], ax=axes[1,0])
ax = sns.countplot(data=new_df, x=new_df['Pressure(in)'].values, hue=new_df['Binary_Severity'], ax=axes[1,1])
ax = sns.countplot(data=new_df, x=new_df['Visibility(mi)'].values, hue=new_df['Binary_Severity'], ax=axes[2,0])
ax = sns.countplot(data=new_df, x=new_df['Wind_Speed(mph)'].values, hue=new_df['Binary_Severity'], ax=axes[2,1])
plt.tight_layout()
plt.grid(False)

plt.figure(figsize=(6, 4))
sns.countplot(data=new_df, x=new_df['Precipitation(in)'].values, hue=new_df['Binary_Severity'])

plt.show()

# %% [markdown]
# ### One Hot Encoding

# %%
# Create a list of states to keep
states_to_keep = ['CA']

# Create a new DataFrame by filtering the rows
onehot_df = new_df[new_df['State'].isin(states_to_keep)]

# %%
onehot_df = pd.get_dummies(onehot_df, columns=['Weather_Condition'], drop_first=True, dtype=int)

# %%
onehot_df
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 728          A-729         3 2016-06-21 10:34:40 2016-06-21 11:04:40
# 729          A-730         3 2016-06-21 10:30:16 2016-06-21 11:16:39
# 730          A-731         2 2016-06-21 10:49:14 2016-06-21 11:19:14
# 731          A-732         3 2016-06-21 10:41:42 2016-06-21 11:11:42
# 732          A-733         2 2016-06-21 10:16:26 2016-06-21 11:04:16
# ...            ...       ...                 ...                 ...
# 7728389  A-7777757         2 2019-08-23 18:03:25 2019-08-23 18:32:01
# 7728390  A-7777758         2 2019-08-23 19:11:30 2019-08-23 19:38:23
# 7728391  A-7777759         2 2019-08-23 19:00:21 2019-08-23 19:28:49
# 7728392  A-7777760         2 2019-08-23 19:00:21 2019-08-23 19:29:42
# 7728393  A-7777761         2 2019-08-23 18:52:06 2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng  Distance(mi)  \
# 728      38.085300 -122.233017         0.000
# 729      37.631813 -122.084167         0.000
# 730      37.896564 -122.070717         0.000
# 731      37.334255 -122.032471         0.000
# 732      37.250729 -121.910713         0.000
# ...            ...         ...           ...
# 7728389  34.002480 -117.379360         0.543
# 7728390  32.766960 -117.148060         0.338
# 7728391  33.775450 -117.847790         0.561
# 7728392  33.992460 -118.403020         0.772
# 7728393  34.133930 -117.230920         0.537
#
#                                                Description  \
# 728      Right hand shoulder blocked due to accident on...
# 729      Accident on I-880 Northbound at Exit 26 Tennys...
# 730      Right lane blocked due to accident on CA-24 We...
# 731      #4 &amp; HOV lane blocked due to accident on I...
# 732      Right hand shoulder blocked due to accident on...
# ...                                                    ...
# 7728389                           At Market St - Accident.
# 7728390    At Camino Del Rio/Mission Center Rd - Accident.
# 7728391  At Glassell St/Grand Ave - Accident. in the ri...
# 7728392     At CA-90/Marina Fwy/Jefferson Blvd - Accident.
# 7728393              At Highland Ave/Arden Ave - Accident.
#
#                       Street          City          County State Zipcode  \
# 728              Magazine St       Vallejo          Solano    CA   94591
# 729                  I-880 N       Hayward         Alameda    CA   94544
# 730                  I-680 N  Walnut Creek    Contra Costa    CA   94595
# 731           N De Anza Blvd     Cupertino     Santa Clara    CA   95014
# 732      Norman Y Mineta Hwy      San Jose     Santa Clara    CA   95118
# ...                      ...           ...             ...   ...     ...
# 7728389         Pomona Fwy E     Riverside       Riverside    CA   92501
# 7728390                I-8 W     San Diego       San Diego    CA   92108
# 7728391     Garden Grove Fwy        Orange          Orange    CA   92866
# 7728392      San Diego Fwy S   Culver City     Los Angeles    CA   90230
# 7728393             CA-210 W      Highland  San Bernardino    CA   92346
#
#           Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 728     2016-06-21 10:54:00            75.0       64.73455         48.0
# 729     2016-06-21 10:54:00            75.0       64.73455         48.0
# 730     2016-06-21 10:53:00            82.9       64.73455         31.0
# 731     2016-06-21 10:56:00            75.9       64.73455         48.0
# 732     2016-06-21 09:50:00            75.2       64.73455         41.0
# ...                     ...             ...            ...          ...
# 7728389 2019-08-23 17:53:00            86.0       86.00000         40.0
# 7728390 2019-08-23 18:53:00            70.0       70.00000         73.0
# 7728391 2019-08-23 18:53:00            73.0       73.00000         64.0
# 7728392 2019-08-23 18:51:00            71.0       71.00000         81.0
# 7728393 2019-08-23 20:50:00            79.0       79.00000         47.0
#
#          Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  \
# 728             30.00            10.0        24.577115           0.008342
# 729             30.06            10.0        24.577115           0.008342
# 730             29.97            10.0        24.577115           0.008342
# 731             30.04            10.0        24.577115           0.008342
# 732             30.06            10.0        24.577115           0.008342
# ...               ...             ...              ...                ...
# 7728389         28.92            10.0        24.577115           0.000000
# 7728390         29.39            10.0        24.577115           0.000000
# 7728391         29.74            10.0        24.577115           0.000000
# 7728392         29.62            10.0        24.577115           0.000000
# 7728393         28.63             7.0        24.577115           0.000000
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 728        False  False     False     False     False    False    False
# 729        False  False     False     False     False    False    False
# 730        False  False     False     False     False    False    False
# 731        False  False     False     False     False    False    False
# 732        False  False     False     False     False    False    False
# ...          ...    ...       ...       ...       ...      ...      ...
# 7728389    False  False     False     False     False    False    False
# 7728390    False  False     False     False     False    False    False
# 7728391    False  False     False     False      True    False    False
# 7728392    False  False     False     False     False    False    False
# 7728393    False  False     False     False     False    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 728           False    False  False            False           False
# 729           False    False  False            False           False
# 730           False    False  False            False           False
# 731           False    False  False            False           False
# 732           False    False  False            False           False
# ...             ...      ...    ...              ...             ...
# 7728389       False    False  False            False           False
# 7728390       False    False  False            False           False
# 7728391       False    False  False            False           False
# 7728392       False    False  False            False           False
# 7728393       False    False  False            False           False
#
#          Turning_Loop Sunset Civil_Twilight Nautical_Twilight  \
# 728             False    Day            Day               Day
# 729             False    Day            Day               Day
# 730             False    Day            Day               Day
# 731             False    Day            Day               Day
# 732             False    Day            Day               Day
# ...               ...    ...            ...               ...
# 7728389         False    Day            Day               Day
# 7728390         False    Day            Day               Day
# 7728391         False    Day            Day               Day
# 7728392         False    Day            Day               Day
# 7728393         False    Day            Day               Day
#
#         Astronomical_Twilight        Duration  Month  Binary_Severity  \
# 728                       Day 0 days 00:30:00      6                1
# 729                       Day 0 days 00:46:23      6                1
# 730                       Day 0 days 00:30:00      6                0
# 731                       Day 0 days 00:30:00      6                1
# 732                       Day 0 days 00:47:50      6                0
# ...                       ...             ...    ...              ...
# 7728389                   Day 0 days 00:28:36      8                0
# 7728390                   Day 0 days 00:26:53      8                0
# 7728391                   Day 0 days 00:28:28      8                0
# 7728392                   Day 0 days 00:29:21      8                0
# 7728393                   Day 0 days 00:29:25      8                0
#
#          Weather_Condition_Cloudy  Weather_Condition_Low Visibility  \
# 728                             0                                 0
# 729                             0                                 0
# 730                             0                                 0
# 731                             0                                 0
# 732                             0                                 0
# ...                           ...                               ...
# 7728389                         0                                 0
# 7728390                         0                                 0
# 7728391                         1                                 0
# 7728392                         0                                 0
# 7728393                         0                                 0
#
#          Weather_Condition_Rain  Weather_Condition_Snow
# 728                           0                       0
# 729                           0                       0
# 730                           0                       0
# 731                           0                       0
# 732                           0                       0
# ...                         ...                     ...
# 7728389                       0                       0
# 7728390                       0                       0
# 7728391                       0                       0
# 7728392                       0                       0
# 7728393                       0                       0
#
# [4191743 rows x 45 columns]

# %%
#creating a new, smaller csv file
# new_df.to_csv('new_df.csv')
