# %%
# %run EDA.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 2.0+ GB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 41 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               datetime64[ns]
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Street                 object
#  11  City                   object
#  12  County                 object
#  13  State                  object
#  14  Zipcode                object
#  15  Weather_Timestamp      datetime64[ns]
#  16  Temperature(F)         float64
#  17  Wind_Chill(F)          float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
#  21  Wind_Speed(mph)        float64
#  22  Precipitation(in)      float64
#  23  Weather_Condition      object
#  24  Amenity                bool
#  25  Bump                   bool
#  26  Crossing               bool
#  27  Give_Way               bool
#  28  Junction               bool
#  29  No_Exit                bool
#  30  Railway                bool
#  31  Roundabout             bool
#  32  Station                bool
#  33  Stop                   bool
#  34  Traffic_Calming        bool
#  35  Traffic_Signal         bool
#  36  Turning_Loop           bool
#  37  Sunrise_Sunset         object
#  38  Civil_Twilight         object
#  39  Nautical_Twilight      object
#  40  Astronomical_Twilight  object
# dtypes: bool(13), datetime64[ns](3), float64(12), int64(1), object(12)
# memory usage: 1.7+ GB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 42 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               datetime64[ns]
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Street                 object
#  11  City                   object
#  12  County                 object
#  13  State                  object
#  14  Zipcode                object
#  15  Weather_Timestamp      datetime64[ns]
#  16  Temperature(F)         float64
#  17  Wind_Chill(F)          float64
#  18  Humidity(%)            float64
#  19  Pressure(in)           float64
#  20  Visibility(mi)         float64
#  21  Wind_Speed(mph)        float64
#  22  Precipitation(in)      float64
#  23  Weather_Condition      object
#  24  Amenity                bool
#  25  Bump                   bool
#  26  Crossing               bool
#  27  Give_Way               bool
#  28  Junction               bool
#  29  No_Exit                bool
#  30  Railway                bool
#  31  Roundabout             bool
#  32  Station                bool
#  33  Stop                   bool
#  34  Traffic_Calming        bool
#  35  Traffic_Signal         bool
#  36  Turning_Loop           bool
#  37  Sunrise_Sunset         object
#  38  Civil_Twilight         object
#  39  Nautical_Twilight      object
#  40  Astronomical_Twilight  object
#  41  Duration               timedelta64[ns]
# dtypes: bool(13), datetime64[ns](3), float64(12), int64(1), object(12), timedelta64[ns](1)
# memory usage: 1.8+ GB
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/3534543569.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True); #extracting the hour from the timestamp
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/162880586.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Wind_Speed(mph)'] = new_df.loc[new_df['Wind_Speed(mph)'] > 100, 'Wind_Speed(mph)'] / 10
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/2472360914.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Temperature(F)'].fillna(value=mean_value_temp, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/2472360914.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Wind_Chill(F)'].fillna(value=mean_value_wind_chill, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/2472360914.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Humidity(%)'].fillna(value=mean_value_humid, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/2472360914.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Pressure(in)'].fillna(value=mean_value_press, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/2472360914.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Visibility(mi)'].fillna(value=mean_value_vis, inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/2472360914.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Wind_Speed(mph)'].fillna(value=mean_value_wind_speed,inplace=True)
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/2472360914.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Precipitation(in)'].fillna(value=mean_value_precip, inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# Index: 4273178 entries, 728 to 7728393
# Data columns (total 40 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               datetime64[ns]
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   Distance(mi)           float64
#  7   Description            object
#  8   Street                 object
#  9   City                   object
#  10  County                 object
#  11  State                  object
#  12  Zipcode                object
#  13  Weather_Timestamp      datetime64[ns]
#  14  Temperature(F)         float64
#  15  Wind_Chill(F)          float64
#  16  Humidity(%)            float64
#  17  Pressure(in)           float64
#  18  Visibility(mi)         float64
#  19  Wind_Speed(mph)        float64
#  20  Precipitation(in)      float64
#  21  Weather_Condition      object
#  22  Amenity                int64
#  23  Bump                   int64
#  24  Crossing               int64
#  25  Give_Way               int64
#  26  Junction               int64
#  27  No_Exit                int64
#  28  Railway                int64
#  29  Roundabout             int64
#  30  Station                int64
#  31  Stop                   int64
#  32  Traffic_Calming        int64
#  33  Traffic_Signal         int64
#  34  Turning_Loop           int64
#  35  Sunrise_Sunset         object
#  36  Civil_Twilight         object
#  37  Nautical_Twilight      object
#  38  Astronomical_Twilight  object
#  39  Duration               timedelta64[ns]
# dtypes: datetime64[ns](3), float64(10), int64(14), object(12), timedelta64[ns](1)
# memory usage: 1.3+ GB
# <class 'pandas.core.frame.DataFrame'>
# Index: 4191743 entries, 728 to 7728393
# Data columns (total 40 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               datetime64[ns]
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   Distance(mi)           float64
#  7   Description            object
#  8   Street                 object
#  9   City                   object
#  10  County                 object
#  11  State                  object
#  12  Zipcode                object
#  13  Weather_Timestamp      datetime64[ns]
#  14  Temperature(F)         float64
#  15  Wind_Chill(F)          float64
#  16  Humidity(%)            float64
#  17  Pressure(in)           float64
#  18  Visibility(mi)         float64
#  19  Wind_Speed(mph)        float64
#  20  Precipitation(in)      float64
#  21  Weather_Condition      object
#  22  Amenity                int64
#  23  Bump                   int64
#  24  Crossing               int64
#  25  Give_Way               int64
#  26  Junction               int64
#  27  No_Exit                int64
#  28  Railway                int64
#  29  Roundabout             int64
#  30  Station                int64
#  31  Stop                   int64
#  32  Traffic_Calming        int64
#  33  Traffic_Signal         int64
#  34  Turning_Loop           int64
#  35  Sunset                 float64
#  36  Civil_Twilight         float64
#  37  Nautical_Twilight      float64
#  38  Astronomical_Twilight  float64
#  39  Duration               timedelta64[ns]
# dtypes: datetime64[ns](3), float64(14), int64(14), object(8), timedelta64[ns](1)
# memory usage: 1.3+ GB

# %%
#due to the size of this dataset and for the sake of time, we will solely be focusing on California since it has the most accidents

# Create a list of states to keep
states_to_keep = ['CA']

# Create a new DataFrame by filtering the rows
cali_df = new_df[new_df['State'].isin(states_to_keep)]

# %%
cali_df
# Out:
#                 ID  Severity          Start_Time            End_Time  \
# 728          A-729         1 2016-06-21 10:34:40 2016-06-21 11:04:40
# 729          A-730         1 2016-06-21 10:30:16 2016-06-21 11:16:39
# 730          A-731         0 2016-06-21 10:49:14 2016-06-21 11:19:14
# 731          A-732         1 2016-06-21 10:41:42 2016-06-21 11:11:42
# [1700854 rows x 43 columns]

# %%
cities_by_accident = cali_df.City.value_counts()
cities_by_accident
# Out:
# City
# Los Angeles                   155841
# Sacramento                     66059
# San Diego                      55330
# San Jose                       34412
# Riverside                      26262
#                                ...
# Travis Afb                         1
# Hyampom                            1
# Shoshone                           1
# South Santa Clara Valley           1
# Russian River-Sonoma Coast         1
# Name: count, Length: 1150, dtype: int64

# %%
cities_by_accident[:10].plot(kind = 'barh');

# %%
#seeing which words in description has the most weights
data = cali_df['Description'].value_counts().to_dict()
wc = WordCloud(width = 900, height = 800, background_color ='white', min_font_size = 10).generate_from_frequencies(data)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
columns_to_plot = ["Amenity","Bump","Crossing","Give_Way","Junction","No_Exit","Railway",
                   "Roundabout","Station","Stop","Traffic_Calming","Traffic_Signal","Turning_Loop"]

# Assume your data is stored in a DataFrame called 'df'
# You can create a new DataFrame with just the binary columns
binary_df = cali_df[columns_to_plot]

# Calculate the frequency of each binary value (0 or 1) in each column
binary_counts = binary_df.sum()

#plot
plt.bar(binary_counts.index, binary_counts.values)
plt.xlabel("POI")
plt.ylabel("Total Number of Accidents")
plt.title("Total Number of Accidents by POI in CA")
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %% [markdown]
# This shows a majority of accidents occurred at road Junctions in California as compared with the whole dataset, it was Traffic Signals.

# %% [markdown]
# ### Number of Accidents per Year in California

# %%
#creating a new column for the year of the accidents 
cali_df['Year'] = cali_df['Start_Time'].dt.year
# Out:
# /var/folders/wr/g705p4v548q9pr0f6xzqsgmw0000gn/T/ipykernel_1054/1843734537.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cali_df['Year'] = cali_df['Start_Time'].dt.year

# %%
cali_df['Year'].value_counts()
# Out:
# Year
# 2022    366592
# 2021    333749
# 2020    277428
# 2019    208405
# 2018    153963
# 2017    150063
# 2016    138224
# 2023     72430
# Name: count, dtype: int64

# %%
ax = sns.histplot(data=cali_df, x=cali_df['Year'], bins=8)
ax.set_title('Number of Accidents per Year in CA')
ax.set_xlabel('Year')
ax.set_ylabel('# of accididents')
plt.show()

# %% [markdown]
# # Modeling

# %%
#installing catboost library
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp39-cp39-macosx_11_0_universal2.whl.metadata (1.2 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.20.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from catboost) (3.8.2)
# Requirement already satisfied: numpy>=1.16.0 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from catboost) (1.26.3)
# Requirement already satisfied: pandas>=0.24 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from catboost) (2.1.3)
# Requirement already satisfied: scipy in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from catboost) (1.11.3)
# Collecting plotly (from catboost)
#   Downloading plotly-5.19.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: six in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from catboost) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from matplotlib->catboost) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from matplotlib->catboost) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from matplotlib->catboost) (6.1.1)
# Collecting tenacity>=6.2.0 (from plotly->catboost)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/julieleung/anaconda3/envs/learn-env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.17.0)
# Downloading catboost-1.2.3-cp39-cp39-macosx_11_0_universal2.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 23.8 MB/s eta 0:00:0000:0100:01
# Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 5.5 MB/s eta 0:00:00
# Downloading plotly-5.19.0-py3-none-any.whl (15.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 22.9 MB/s eta 0:00:00a 0:00:01
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, graphviz, plotly, catboost
# Successfully installed catboost-1.2.3 graphviz-0.20.1 plotly-5.19.0 tenacity-8.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics, preprocessing
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, accuracy_score, r2_score
from sklearn.metrics import recall_score, precision_score, precision_recall_curve, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer

from catboost import CatBoostClassifier
from xgboost import XGBClassifier

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from imblearn.pipeline import Pipeline

from scipy.stats import uniform

from collections import Counter

import shap

# %%
cali_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1700854 entries, 728 to 7728393
# Data columns (total 44 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   ID                                object
#  1   Severity                          int64
#  2   Start_Time                        datetime64[ns]
#  3   End_Time                          datetime64[ns]
#  4   Start_Lat                         float64
#  5   Start_Lng                         float64
#  6   Distance(mi)                      float64
#  7   Description                       object
#  8   Street                            object
#  9   City                              object
#  10  County                            object
#  11  State                             object
#  12  Zipcode                           object
#  13  Weather_Timestamp                 datetime64[ns]
#  14  Temperature(F)                    float64
#  15  Wind_Chill(F)                     float64
#  16  Humidity(%)                       float64
#  17  Pressure(in)                      float64
#  18  Visibility(mi)                    float64
#  19  Wind_Speed(mph)                   float64
#  20  Precipitation(in)                 float64
#  21  Amenity                           int64
#  22  Bump                              int64
#  23  Crossing                          int64
#  24  Give_Way                          int64
#  25  Junction                          int64
#  26  No_Exit                           int64
#  27  Railway                           int64
#  28  Roundabout                        int64
#  29  Station                           int64
#  30  Stop                              int64
#  31  Traffic_Calming                   int64
#  32  Traffic_Signal                    int64
#  33  Turning_Loop                      int64
#  34  Sunset                            float64
#  35  Civil_Twilight                    float64
#  36  Nautical_Twilight                 float64
#  37  Astronomical_Twilight             float64
#  38  Duration                          timedelta64[ns]
#  39  Weather_Condition_Cloudy          int64
#  40  Weather_Condition_Low Visibility  int64
#  41  Weather_Condition_Rain            int64
#  42  Weather_Condition_Snow            int64
#  43  Year                              int32
# dtypes: datetime64[ns](3), float64(14), int32(1), int64(18), object(7), timedelta64[ns](1)
# memory usage: 577.5+ MB

# %%
#defining the predictor/target variables
X = cali_df.drop(columns=['Binary_Severity', 'Severity', 'Description', 'Street', 'City', 'County', 'State', 'Zipcode',
                        'Weather_Timestamp', 'Start_Time', 'End_Time','Duration', 'ID'], axis=1)
y = cali_df['Binary_Severity']

# %%
#splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=88)

# %% [markdown]
# ### Logistic Regression with SMOTE

# %%
#to address the class imbalanced, we willl be performing SMOTE
cali_df['Severity'].value_counts()
# Out:
# Severity
# 0    1421394
# 1     279460
# Name: count, dtype: int64

# %%
smote = SMOTE(random_state=88)

X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

ss = StandardScaler()

ss.fit(X_train_resampled)

X_train_scaled = ss.transform(X_train_resampled)
X_test_scaled = ss.transform(X_test)

print('Original dataset shape', Counter(y_train))
print('Resample dataset shape', Counter(y_train_resampled))
# Out:
# Original dataset shape Counter({0: 1066162, 1: 209478})
# Resample dataset shape Counter({1: 1066162, 0: 1066162})

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train_scaled, y_train_resampled)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test_scaled)

# %%
ConfusionMatrixDisplay.from_estimator(logreg, X_test_scaled, y_test);

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.7363892063760836

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.82    355232
#            1       0.35      0.70      0.47     69982
#
#     accuracy                           0.74    425214
#    macro avg       0.64      0.72      0.65    425214
# weighted avg       0.83      0.74      0.77    425214

# %% [markdown]
# ### Random Forest with SMOTE

# %%
rf = RandomForestClassifier(random_state=88)

# %%
rf.fit(X_train_resampled, y_train_resampled)
# Out:
# RandomForestClassifier(random_state=88)

# %%
y_pred = rf.predict(X_test)

# %%
ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test);

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.8822569341555075

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93    355232
#            1       0.62      0.75      0.68     69982
#
#     accuracy                           0.88    425214
#    macro avg       0.78      0.83      0.80    425214
# weighted avg       0.89      0.88      0.89    425214

# %% [markdown]
# ## Tuning Hyperparameters with GridSearchCV

# %%
pipe = Pipeline([('random_forest', RandomForestClassifier(random_state=88))])

params = {'random_forest__n_estimators': np.arange(20,100,40),
          'random_forest__criterion':['entropy'],
          'random_forest__max_depth': np.arange(8,12,2)}

grid = GridSearchCV(pipe, param_grid=params, cv=5)
grid.fit(X_train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('random_forest',
#                                         RandomForestClassifier(random_state=88))]),
#              param_grid={'random_forest__criterion': ['entropy'],
#                          'random_forest__max_depth': array([ 8, 10]),
#                          'random_forest__n_estimators': array([20, 60])})

# %%
best_est = grid.best_estimator_
best_est
# Out:
# Pipeline(steps=[('random_forest',
#                  RandomForestClassifier(criterion='entropy', max_depth=10,
#                                         n_estimators=60, random_state=88))])

# %%
#running Random Forest with the best parameters
rf_clf = RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=60,
                       random_state=88)
rf_clf.fit(X_train_resampled, y_train_resampled)

y_pred_rf = rf_clf.predict(X_test)
metrics.accuracy_score(y_test, y_pred_rf)
# Out:
# 0.7619269356135969

# %% [markdown]
# ### RandomizedSearchCV

# %%
logistic = LogisticRegression(solver='saga', tol=1e-2, max_iter=200, random_state=88)
distributions = dict(C=uniform(loc=0, scale=4), penalty=['l2', 'l1'])
rand_search = RandomizedSearchCV(logistic, distributions, random_state=88)
search = rand_search.fit(X_train_scaled, y_train_resampled)
search.best_params_
# Out:
# {'C': 0.3596887787358143, 'penalty': 'l1'}

# %% [markdown]
# # GridSearchCV

# %%
logreg_pipe = Pipeline([("logreg", LogisticRegression(random_state=88))])

params = {'logreg__C': [0.01, 0.1, 1],
          'logreg__class_weight': ['balanced'],
          'logreg__penalty': ['l1'],
          'logreg__solver': ['liblinear', 'saga']}

grid_logreg = GridSearchCV(logreg_pipe, param_grid=params, cv=5, error_score='raise')
grid_logreg.fit(X_train_scaled, y_train_resampled)
# Out:
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('logreg',
#                                         LogisticRegression(random_state=88))]),
#              param_grid={'logreg__C': [0.01, 0.1, 1],
#                          'logreg__class_weight': ['balanced'],
#                          'logreg__penalty': ['l1'],
#                          'logreg__solver': ['liblinear', 'saga']})

# %%
best_est = grid_logreg.best_estimator_
best_est
# Out:
# Pipeline(steps=[('logreg',
#                  LogisticRegression(C=0.1, class_weight='balanced',
#                                     penalty='l1', random_state=88,
#                                     solver='liblinear'))])

# %%
#running Random Forest with the best parameters
tuned_logreg = LogisticRegression(C=0.3596887787358143, class_weight='balanced', penalty='l1',
                   random_state=88, solver='liblinear')

tuned_logreg.fit(X_train_scaled, y_train_resampled)

y_pred = tuned_logreg.predict(X_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# X has feature names, but LogisticRegression was fitted without feature names
# 0.8354193417902515

# %%
#running Random Forest with the best parameters
tuned_logreg = LogisticRegression(C=0.1, class_weight='balanced', penalty='l1',
                   random_state=88, solver='liblinear')

tuned_logreg.fit(X_train_scaled, y_train_resampled)

y_pred = tuned_logreg.predict(X_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# X has feature names, but LogisticRegression was fitted without feature names
# 0.8354193417902515

# %% [markdown]
# ### Catboost Model
